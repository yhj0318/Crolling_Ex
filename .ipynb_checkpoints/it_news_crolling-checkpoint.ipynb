# %%
pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\user\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (from bs4) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pprint import pprint
import requests
from bs4 import BeautifulSoup as bs

# %%
html = requests.get('https://media.naver.com/press/025?sid=105')
pprint(html.text)
# Out:
# ('<!doctype html>\n'
#  '<html lang="ko">\n'
#  '\t<head>\n'
#  '\t\t<title id="browserTitleArea">\n'
#  '\n'
#  '\n'
#  '중앙일보 :: 네이버뉴스\n'
#  '</title>\n'
#  '\t\t\n'
#  '\n'
#  '\n'
#  '<script>\n'
#  '\tfunction isMobileDevice() {\n'
#  '\t\treturn /^.*(iPhone|iPod|iPad|Android).*/.test(navigator.userAgent);\n'
#  '\t}\n'
#  '</script>\n'
#  '<script>\n'
#  '\t(function () {\n'
#  '\t\ttry {\n'
#  '\t\t\tif (isMobileDevice() && isAbleApplyPrefersColorScheme()) {\n'
#  '\t\t\t\t\n'
#  '\t\t\t\tdocument.querySelector("html").classList.add("DARK_THEME");\n'
#  '\t\t\t}\n'
#  '\t\t} catch(e) {}\n'
#  '\n'
#  '\t\tfunction isAbleApplyPrefersColorScheme() {\n'
#  '\t\t\t\n'
#  '\t\t\tif (window.matchMedia("(prefers-color-scheme)").matches === false) {\n'
#  '\t\t\t\treturn false;\n'
#  '\t\t\t}\n'
#  '\n'
#  '\t\t\tvar userAgent = navigator.userAgent;\n'
#  '\n'
#  '\t\t\tif (userAgent.indexOf("NAVER") > -1) {\n'
#  '\t\t\t\t\n'
#  '\t\t\t\tif (/.*NAVER\\([a-zA-Z]*;\\s[a-zA-Z]*;\\s([0-9]*);/.test(userAgent)) '
#  '{\n'
#  '\t\t\t\t\treturn Number(RegExp.$1) >= 1000;\n'
#  '\t\t\t\t}\n'
#  '\t\t\t} else {\n'
#  '\t\t\t\t\n'
#  '\t\t\t\treturn document.cookie.indexOf("NSCS=1") > -1;\n'
#  '\t\t\t}\n'
#  '\n'
#  '\t\t\treturn false;\n'
#  '\t\t}\n'
#  '\t})();\n'
#  '</script>\n'
#  '\n'
#  '\t\t<script>\n'
#  "\t\tvar g_ssc = 'news.v3_press' || null;\n"
#  '\t\t</script>\n'
#  '\t\t<meta charset="utf-8">\n'
#  '<meta name="viewport" '
#  'content="width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no,target-densitydpi=medium-dpi"/>\n'
#  '<link rel="stylesheet" type="text/css" '
#  'href="https://ssl.pstatic.net/static.news/mnews/resources/20230906_104903/css/generated/other.css" '
#  '/>\n'
#  '\t\t\t<link rel="shortcut icon" type="image/x-icon" '
#  'href="https://mimgnews.pstatic.net/image/news/m/2023/favicon/favicon.ico" '
#  '/>\n'
#  '<script>\n'
#  '\t(function(){\n'
#  '\t\tvar userAgent = navigator.userAgent;\n'
#  '\t\tvar result = [];\n'
#  '\n'
#  "\t\tif(userAgent.indexOf('Android') > -1){\n"
#  '\t\t\tresult = [\n'
#  '\t\t\t\t\'<link rel="apple-touch-icon-precomposed" sizes="72x72" '
#  'href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" '
#  "/>',\n"
#  '\t\t\t\t\'<link rel="apple-touch-icon-precomposed" sizes="96x96" '
#  'href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" '
#  "/>',\n"
#  '\t\t\t\t\'<link rel="apple-touch-icon-precomposed" sizes="144x144" '
#  'href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" '
#  "/>',\n"
#  '\t\t\t\t\'<link rel="apple-touch-icon-precomposed" sizes="192x192" '
#  'href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" '
#  "/>'\n"
#  '\t\t\t];\n'
#  "\t\t}else if(userAgent.indexOf('iPhone') > -1){\n"
#  '\t\t\tresult = [\n'
#  '\t\t\t\t\'<link rel="apple-touch-icon-precomposed" sizes="120X120" '
#  'href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_2x_120X120.png" '
#  "/>',\n"
#  '\t\t\t\t\'<link rel="apple-touch-icon-precomposed" sizes="180x180" '
#  'href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_3x_180X180.png" '
#  "/>'\n"
#  '\t\t\t];\n'
#  "\t\t}else if(userAgent.indexOf('iPad') > -1){\n"
#  '\t\t\tresult = [\n'
#  '\t\t\t\t\'<link rel="apple-touch-icon-precomposed" sizes="167x167" '
#  'href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPadPro_2x_167X167.png" '
#  "/>',\n"
#  '\t\t\t\t\'<link rel="apple-touch-icon-precomposed" sizes="152x152" '
#  'href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPad_2x_152X152.png" '
#  "/>'\n"
#  '\t\t\t];\n'
#  '\t\t}\n'
#  "\t\tdocument.write(result.join('\\n'));\n"
#  '\t})();\n'
#  '</script>\n'
#  '\n'
#  '<script type="text/javascript" '
#  'src="https://ssl.pstatic.net/static.news/mnews/resources/20230906_104903/js/generated/statistics_jquery.js"></script>\n'
#  '\t\n'
#  '\n'
#  '<script>\n'
#  '\n'
#  "document.documentElement.setAttribute('data-useragent', "
#  'navigator.userAgent);\n'
#  '\n'
#  '\n'
#  'function showNoImage(elImg, type) {\n'
#  '    switch (type) {\n'
#  '        \n'
#  '        case "remove":\n'
#  '            try {\n'
#  '                elImg.parentNode.removeChild(elImg);\n'
#  '            } catch(e) {}\n'
#  '            break;\n'
#  '\n'
#  '        \n'
#  '        case "removeParent":\n'
#  '            try {\n'
#  "                elImg.parentNode.outerHTML = '';\n"
#  '            } catch(e) {}\n'
#  '            break;\n'
#  '\n'
#  '        \n'
#  '        case "alt":\n'
#  '            elImg.outerHTML = (\'<span class="noimage_text '
#  '{imgClassName}">\' + (elImg.alt || "") + \'</span>\')\n'
#  '                \n'
#  "                .replace('{imgClassName}', elImg.className);\n"
#  '            break;\n'
#  '\n'
#  '\t\t\n'
#  '\t\tcase "class" :\n'
#  '\t\t\tvar outerHTMLSource = Number(elImg.getAttribute("height")) > 0?\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t\'<span class="noimage_wrap {imgClassName}" style="height:\' + '
#  'elImg.getAttribute("height") + \'px;"><span '
#  'class="noimage"></span></span>\':\n'
#  '\t\t\t\t\'<span class="noimage_wrap {imgClassName}"><span '
#  'class="noimage"></span></span>\';\n'
#  "\t\t\telImg.outerHTML = outerHTMLSource.replace('{imgClassName}', "
#  'elImg.className);\n'
#  '\t\t\tbreak;\n'
#  '\n'
#  '        \n'
#  '        default:\n'
#  '            \n'
#  '            elImg.outerHTML = Number(elImg.getAttribute("height")) > 0?\n'
#  '                \n'
#  '                \'<span class="noimage_wrap" style="height:\' + '
#  'elImg.getAttribute("height") + \'px;"><span '
#  'class="noimage"></span></span>\':\n'
#  '                \'<span class="noimage_wrap"><span '
#  'class="noimage"></span></span>\';\n'
#  '    }\n'
#  '}\n'
#  '\n'
#  '\n'
#  'function doAfterLoadEnd(callback, callbackOnPersisted) {\n'
#  '    var eventName = "onpageshow" in window ? "pageshow" : "load";\n'
#  '\n'
#  '    callback = callback || function(){};\n'
#  '    callbackOnPersisted = callbackOnPersisted || function(){};\n'
#  '\n'
#  '    window.addEventListener(eventName, function(e) {\n'
#  '        try{\n'
#  '            if(Boolean(e.persisted)){  \n'
#  '                callbackOnPersisted();\n'
#  '                return;\n'
#  '            }\n'
#  '        }catch(e){}\n'
#  '\n'
#  '        callback();\n'
#  '    });\n'
#  '}\n'
#  '</script>\n'
#  '\t\t\n'
#  '\n'
#  '\n'
#  '\n'
#  '    \n'
#  '        \n'
#  '        \n'
#  '            <script type="text/javascript" '
#  'src="https://ssl.pstatic.net/static.news/mnews/resources/20230906_104903/js/generated/news.mobile.js"></script>\n'
#  '        \n'
#  '            <script type="text/javascript" '
#  'src="https://ssl.pstatic.net/static.news/mnews/resources/20230906_104903/js/generated/presshome.dependency.js"></script>\n'
#  '        \n'
#  '    \n'
#  '    \n'
#  '\n'
#  '<script>\n'
#  '    (function() {\n'
#  '        var path = location.pathname;\n'
#  "        var isLiveUrl = path.indexOf('/press/' + '025/live') >= 0;\n"
#  '        var agentInfo = news.Util.getAgentInfo();\n'
#  '        var isAndroidMobile = agentInfo.bIsAndroid && '
#  'agentInfo.bMobileOrTablet;\n'
#  '        var isLiveViewer = agentInfo.bIsLiveViewer;\n'
#  '\n'
#  '        if (isLiveUrl && isAndroidMobile && isLiveViewer) {\n'
#  '            '
#  "document.querySelector('html').classList.add('NAVER_APP_LIVE_VIEWER');\n"
#  '        }\n'
#  '    })();\n'
#  '</script>\n'
#  '\n'
#  '<script>\n'
#  'function goMainChannelUrl() {\n'
#  '    if (isMobileDevice()) {\n'
#  '        return news.Util.goMainChannel();\n'
#  '    } else {\n'
#  '        return window.location = "https://news.naver.com";\n'
#  '    }\n'
#  '}\n'
#  '</script>\n'
#  '\n'
#  '\t\t<meta property="og:title"\t\t\tcontent="중앙일보 언론사홈"/>\n'
#  '<meta property="og:type"\t\t\tcontent="website"/>\n'
#  '<meta property="og:url"\t\t\t\t'
#  'content="https://media.naver.com/press/025"/>\n'
#  '<meta property="og:image"\t\t\t'
#  'content="https://mimgnews.pstatic.net/image/upload/office_logo/025/2021/08/24/logo_025_41_20210824111041.png"/>\n'
#  '<meta property="og:description"\t\tcontent="언론사 주요 뉴스와 속보를 만나볼 수 있습니다."/>\n'
#  '<meta property="og:article:author"\tcontent="네이버"/>\n'
#  '<meta name="twitter:card"\t\t\tcontent="summary">\n'
#  '<meta name="twitter:title"\t\t\tcontent="중앙일보 언론사홈">\n'
#  '<meta name="twitter:site"\t\t\tcontent="네이버 뉴스">\n'
#  '<meta name="twitter:creator"\t\tcontent="네이버 뉴스">\n'
#  '<meta name="twitter:image"\t\t\t'
#  'content="https://mimgnews.pstatic.net/image/upload/office_logo/025/2021/08/24/logo_025_41_20210824111041.png">\n'
#  '<meta name="twitter:description"\tcontent="언론사 주요 뉴스와 속보를 만나볼 수 있습니다.">\n'
#  '\n'
#  '\t\t<script>\n'
#  '    \n'
#  '    (function () {\n'
#  '        var isUnderIE10 = navigator.appName === "Microsoft Internet '
#  'Explorer";\n'
#  '        if (!isUnderIE10) {\n'
#  '            var script = document.createElement("script");\n'
#  '            script.async = true;\n'
#  '            script.src = '
#  '"https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";\n'
#  '            document.head.appendChild(script);\n'
#  '        }\n'
#  '    })();\n'
#  '\n'
#  '    \n'
#  '    window.gladsdk = window.gladsdk || { cmd: [] };\n'
#  '    window.gladsdk.cmd.push(function () {\n'
#  '        \n'
#  '        window.gladsdk.setGlobalConfig({\n'
#  '            enablePersistAd: true\n'
#  '        });\n'
#  '\n'
#  '        \n'
#  '        var adUnits = [];\n'
#  '    \n'
#  '        adUnits.push({\n'
#  '            adUnitId: "m_news",\n'
#  '            adSlotElementId: "nmap_press_home",\n'
#  '            customParam: {\n'
#  '                calp: "nhome",\n'
#  '                oid: "025",\n'
#  '                directSalesPct : 0\n'
#  '            }\n'
#  '        });\n'
#  '    \n'
#  '        for (let i = 0; i < adUnits.length; i++) {\n'
#  '            window.gladsdk.defineAdSlot(adUnits[i]);\n'
#  '        }\n'
#  '\n'
#  '        \n'
#  '        var htmlClass = '
#  'document.querySelector("html").getAttribute("class");\n'
#  '        if (htmlClass && htmlClass.indexOf("DARK_THEME") > -1) {\n'
#  '            window.gladsdk.setHostMeta("theme", "system");\n'
#  '        }\n'
#  '    });\n'
#  '</script>\n'
#  '\n'
#  '\t</head>\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\t\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '<body class=" body_press as_body_type_a  _font_size_setting_target" '
#  'style="color: #393a3c;">\n'
#  '\t<script>\n'
#  '    (function(){\n'
#  '        try{\n'
#  '            var settingTarget = '
#  "document.querySelector('._font_size_setting_target');\n"
#  '            var defaultFontSize = '
#  "/(?:\\s|^)?NFS=(\\d)(?:;|$)/.test(document.cookie)? RegExp.$1: '2';\n"
#  "            var newFontSizeClass = 'bfsize' + "
#  '(parseInt(defaultFontSize)-1);\n'
#  "            if(newFontSizeClass === 'bfsize0') {\n"
#  '            \treturn;\n'
#  '\t\t\t}\n'
#  '\n'
#  '            settingTarget.className = settingTarget.className + " " + '
#  'newFontSizeClass;\n'
#  '        }catch(e){}\n'
#  '    })();\n'
#  '    </script>\n'
#  '\t<div class="u_skip"><a href="#ct">본문 바로가기</a></div>\n'
#  '    \n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '<section class="news_header as_white_type">\n'
#  '    <header class="nh_header" role="banner">\n'
#  '        <div class="Ngnb">\n'
#  '            <div class="Ngnb_inner">\n'
#  '                <div class="Ngnb_both">\n'
#  '                    <div class="Ngnb_left">\n'
#  '                        <span class="Ngnb_logo"><a '
#  'href="https://www.naver.com" class="Nlogo_link" '
#  'onclick="nclk(event,\'gnb.naver\',\'\',\'\');"><span '
#  'class="Nicon_logo">NAVER</span></a></span>\n'
#  '                        <div class="Ngnb_service">\n'
#  '                            <h1 class="Nservice_item">\n'
#  '                                <a href="https://news.naver.com/main" '
#  'onclick="nclk(event,\'gnb.news\',\'\',\'\');">\n'
#  '                                    <span class="Nicon_service ">뉴스</span>\n'
#  '                                </a>\n'
#  '                            </h1>\n'
#  '                            \n'
#  '                            \n'
#  '                            <span class="Nservice_subitem">\n'
#  '\t\t\t\t\t\t\t\t<a href="https://m.entertain.naver.com/home" '
#  'data-mpurl=\'{"m":"https://m.entertain.naver.com/home","p":"https://entertain.naver.com/home"}\' '
#  'onclick="nclk(event,\'gnb.enter\',\'\',\'\');">\n'
#  '\t\t\t\t\t\t\t\t\t<span class="Nicon_family Nicon_entertain">연예</span>\n'
#  '\t\t\t\t\t\t\t\t</a>\n'
#  '\t\t\t\t\t\t\t</span>\n'
#  '                            \n'
#  '                            \n'
#  '                            <span class="Nservice_subitem">\n'
#  '\t\t\t\t\t\t\t\t<a href="https://m.sports.naver.com/" '
#  'data-mpurl=\'{"m":"https://m.sports.naver.com/","p":"https://sports.news.naver.com/index"}\' '
#  'onclick="nclk(event,\'gnb.sports\',\'\',\'\');">\n'
#  '\t\t\t\t\t\t\t\t\t<span class="Nicon_family Nicon_sports">스포츠</span>\n'
#  '\t\t\t\t\t\t\t\t</a>\n'
#  '\t\t\t\t\t\t\t</span>\n'
#  '                            \n'
#  '                            <span class="Nservice_subitem">\n'
#  '\t\t\t\t\t\t\t\t<a href="https://weather.naver.com/" '
#  'onclick="nclk(event,\'gnb.weather\',\'\',\'\');">\n'
#  '\t\t\t\t\t\t\t\t\t<span class="Nicon_family Nicon_weather">날씨</span>\n'
#  '\t\t\t\t\t\t\t\t</a>\n'
#  '\t\t\t\t\t\t\t</span>\n'
#  '                            <span class="Nservice_subitem">\n'
#  '\t\t\t\t\t\t\t\t<a href="https://contents.premium.naver.com/" '
#  'onclick="nclk(event,\'gnb.premium\',\'\',\'\');">\n'
#  '\t\t\t\t\t\t\t\t\t<span class="Nicon_family Nicon_premium">프리미엄</span>\n'
#  '\t\t\t\t\t\t\t\t</a>\n'
#  '\t\t\t\t\t\t\t</span>\n'
#  '                        </div>\n'
#  '                    </div>\n'
#  '                    \n'
#  '<div class="Ngnb_right">\n'
#  '    <div class="Ngnb_group">\n'
#  '        <div id="gnb" class="gnb_dark_type2"></div>\n'
#  '    </div>\n'
#  '    \n'
#  '    <div class="Ngnb_search is_hidden _search_content"></div>\n'
#  '    <div class="Ngnb_tool">\n'
#  '        <a href="javascript:;"\n'
#  '           class="Ntool_button _search_content_toggle_btn"\n'
#  '           onclick="nclk(event,\'gnb.sch\',\'\',\'\');"><span '
#  'class="Nicon_search">검색</span></a>\n'
#  '    </div>\n'
#  '</div>\n'
#  '\n'
#  '                </div>\n'
#  '            </div>\n'
#  '        </div>\n'
#  '    </header>\n'
#  '</section>\n'
#  '\n'
#  '<hr>\n'
#  '\t\n'
#  '    \n'
#  '    \n'
#  '        \n'
#  '    \n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '<div class="press_wrap">\n'
#  '<div class="press_container">\n'
#  '<section class="press_content">\n'
#  '<h2 class="u_skip">언론사 개별 홈</h2>\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '<header class="press_hd as_type_a  _press_header" style="display:none;; '
#  'color: #393a3c;">\n'
#  '\t<div class="press_hd_bg" style="background-color: #92908c; color: '
#  '#92908c;">\n'
#  '\t\t\n'
#  '\t\t\n'
#  '\t\t<div class="press_hd_bg_inner">\n'
#  '\t\t\t\n'
#  '\t\t\t<img '
#  'src="https://imgnews.pstatic.net/image/upload/spubs/K7G0000025/cover/2021/12/15/A_103552662.png?type=u850_200" '
#  'alt="" class="press_hd_bg_img" onerror="showNoImage(this, \'remove\')">\n'
#  '\t\t\t\n'
#  '\t\t\t<i class="press_hd_bg_gradient_left"></i>\n'
#  '\t\t\t<i class="press_hd_bg_gradient_right"></i>\n'
#  '\t\t</div>\n'
#  '\t</div>\n'
#  '\t<a href="#" class="press_hd_prev _back_btn" '
#  'onclick="nclk(event,\'hom.back\',025,\'\');">이전</a>\n'
#  '\t\n'
#  '\t\t<div class="press_hd_else _press_list_wrapper">\n'
#  '\t\t\t<a href="javascript:;" class="press_hd_else_button _press_list_btn" '
#  'onclick="nclk(event,\'hom.menu\',025,\'\');">\n'
#  '\t\t\t\t<span class="u_hc">전체 언론사 홈</span>\n'
#  '\t\t\t</a>\n'
#  '\t\t</div>\n'
#  '\n'
#  '\t\n'
#  '\t<div class="press_hd_share">\n'
#  '\t\t\n'
#  '\t\t\n'
#  '\t\t<a href="#"  id="spiButton" class="naver-splugin spi_sns_share '
#  'u_btn_sns_share" onclick="nclk(event,\'hom.share\',025,\'\');"\n'
#  '\t\t   data-style="standard"\n'
#  '\t\t   data-url="https://media.naver.com/press/025"\n'
#  '\t\t   data-title="중앙일보 언론사 페이지 :: 네이버"\n'
#  '\t\t   data-mail-url="https://media.naver.com/press/025?lfrom=mail"\n'
#  '\t\t   data-blog-url="https://media.naver.com/press/025?lfrom=blog"\n'
#  '\t\t   data-blog-source-type="3"\n'
#  '\t\t   data-blog-blog-id="naver"\n'
#  '\t\t   data-cafe-url="https://media.naver.com/press/025?lfrom=cafe"\n'
#  '\t\t   data-cafe-source-type="3"\n'
#  '\t\t   data-memo-url="https://media.naver.com/press/025?lfrom=memo"\n'
#  '\t\t   data-calendar-url="https://media.naver.com/press/025?lfrom=calendar"\n'
#  '\t\t   data-band-url="https://media.naver.com/press/025?lfrom=band"\n'
#  '\t\t   data-line-url="https://media.naver.com/press/025?lfrom=line"\n'
#  '\t\t   data-kakaotalk-url="https://media.naver.com/press/025?lfrom=kakao"\n'
#  '\t\t   data-kakaostory-display="off"\n'
#  '\t\t   '
#  'data-kakaotalk-image-url="https://ssl.pstatic.net/static.news/image/news/m/2015/10/press_logo/025_1200x630.jpg"\n'
#  '\t\t   data-facebook-url="https://media.naver.com/press/025?lfrom=facebook"\n'
#  '\t\t   data-twitter-url="https://media.naver.com/press/025?lfrom=twitter"\n'
#  '\t\t   data-mypeople-url="https://media.naver.com/press/025?lfrom=mypeople"\n'
#  '\t\t   data-friend-display="on"\n'
#  '\t\t   data-friend-url="https://media.naver.com/press/025?lfrom=friend">\n'
#  '\t\t\t<span class="naver-splugin-c send_caption"><span class="u_hc">SNS '
#  '보내기</span></span>\n'
#  '\t\t</a>\n'
#  '\t</div>\n'
#  '\n'
#  '\t<div class="press_hd_main">\n'
#  '\t\t<div class="press_hd_main_inner">\n'
#  '\t\t\t<div class="press_hd_ci" style="background-color: #393a3c;">\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t<a href="/press/025" class="press_hd_ci_image" '
#  'onclick="nclk(event,\'hom.logo\',025,\'\');">\n'
#  '\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\t<img '
#  'src="https://imgnews.pstatic.net/image/upload/spubs/K7G0000025/logo/2021/08/20/A_163345038.png?type=u144_144" '
#  'alt="중앙일보" onerror="showNoImage(this)">\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\n'
#  '\t\t\t\t</a>\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t<a href="https://www.joongang.co.kr/" class="press_hd_ci_home" '
#  'onclick="nclk(event,\'hom.url\',025,\'\');">홈페이지</a>\n'
#  '\t\t\t\t\n'
#  '\t\t\t</div>\n'
#  '\t\t\t<div class="press_hd_info">\n'
#  '\t\t\t\t<div class="press_hd_main_info">\n'
#  '\t\t\t\t\t<div class="press_hd_top">\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t<h3 class="press_hd_name">\n'
#  '\t\t\t\t\t\t\t<a href="https://www.joongang.co.kr/" '
#  'class="press_hd_name_link" onclick="nclk(event,\'hom.url\',025,\'\');">\n'
#  '\t\t\t\t\t\t\t\t중앙일보<i class="press_hd_name_link_home"></i>\n'
#  '\t\t\t\t\t\t\t</a>\n'
#  '\t\t\t\t\t\t</h3>\n'
#  '\t\t\t\t\t\t<div class="press_hd_btns_area">\n'
#  '\t\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\t\t<div class="press_hd_subscribe_btnwrap '
#  '_press_hd_subscribe_btnwrap"></div>\n'
#  '\t\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t</div>\n'
#  '\t\t\t\t\t</div>\n'
#  '\t\t\t\t\t\n'
#  '\t\t\t\t\t<p class="press_hd_desc">현장의 진실을 중앙에 두다</p>\n'
#  '\t\t\t\t</div>\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\n'
#  '\t\t\t\t\t\n'
#  '\t\t\t\t\t<div class="press_hd_subscribe">\n'
#  '\t\t\t\t\t\t<em class="press_hd_subscribe_term _follower_label" '
#  'style="display:none;">구독</em>\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t<span class="press_subscribe_badge '
#  '_follower_count_million_badge" style="display:none;"></span>\n'
#  '\t\t\t\t\t</div>\n'
#  '\t\t\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t</div>\n'
#  '\n'
#  '\t\t\t\n'
#  '\t\t</div>\n'
#  '\t</div>\n'
#  '</header>\n'
#  '\n'
#  '<script>\n'
#  '\tfunction initShare() {\n'
#  '\t\tnew news.JsLoader().setConfig({\n'
#  "\t\t\t'sCharSet': 'utf-8' // default\n"
#  '\t\t}).load(\n'
#  "\t\t\t\t['https://ssl.pstatic.net/spi/js/release/ko_KR/splugin.m.js?v=' + "
#  'Math.floor(new Date().getTime() / 1200000)],\n'
#  '\t\t\t\tfunction() {\n'
#  '\t\t\t\t\twindow.__splugin = SocialPlugIn_Core({\n'
#  '\t\t\t\t\t\t// nEvent Key\n'
#  '\t\t\t\t\t\t"evKey"  : "news",\n'
#  '\t\t\t\t\t\t"dimmed" : "fixed",\n'
#  '\t\t\t\t\t\t"darkMode"    : isDarkShareLayer(),\n'
#  '\t\t\t\t\t\t"serviceName" : "뉴스",\n'
#  '\t\t\t\t\t\t"sourceName" : "",\n'
#  '\t\t\t\t\t\t"onClick"     : function(button) {},\n'
#  '\t\t\t\t\t\t"onShow"      : function() {},\n'
#  '\t\t\t\t\t\t"onHide"      : function() {},\n'
#  '\t\t\t\t\t\t"onResize"    : function(event) {},\n'
#  '\t\t\t\t\t\t"onRotate"    : function(event) {}\n'
#  '\t\t\t\t\t});\n'
#  '\t\t\t\t}\n'
#  '\t\t);\n'
#  '\t}\n'
#  '\n'
#  '\tfunction initPressList() {\n'
#  "\t\tvar cpType = 'News';\n"
#  "\t\tvar popupUrl = '/press/popup?cpType=' + cpType;\n"
#  '\t\tvar pressListPopup = new '
#  "PressHomeMainManager.PressListPopup('._press_list_btn', {\n"
#  "\t\t\tselectedOfficeId: '025',\n"
#  '\t\t\tpressListPopupUrl: popupUrl,\n'
#  '\t\t\twrapper: "._press_list_wrapper"\n'
#  '\t\t});\n'
#  '\n'
#  '\t\treturn pressListPopup;\n'
#  '\t}\n'
#  '\n'
#  '\tfunction initPressHomeLnb(params) {\n'
#  "        var officeId = '025';\n"
#  '        var isChannelFollowerVisible = false;\n'
#  "\t\tvar welMillionBadgeArea = $('._follower_count_million_badge');\n"
#  "\t\tvar welFollowerLabel = $('._follower_label');\n"
#  '\t\tvar isMillionBadgeVisible = welMillionBadgeArea.length > 0;\n'
#  "\t\tvar isLiveViewer = $('.NAVER_APP_LIVE_VIEWER').length > 0;\n"
#  '\t\tvar path = location.pathname;\n'
#  "\t\tvar isLiveUrl = path.indexOf('/press/' + officeId + '/live') >= 0;\n"
#  '\n'
#  '        /* 채널구독수 */\n'
#  '        if (isChannelFollowerVisible || isMillionBadgeVisible) {\n'
#  '\t\t\tvar channelFollowerCount = new '
#  "PressHomeMainManager.ChannelFollowerCount('._channel_follower_count', {\n"
#  '\t\t\t\tofficeId: officeId,\n'
#  '\t\t\t});\n'
#  '\t\t\tif (isChannelFollowerVisible) {\n'
#  '\t\t\t\t'
#  'channelFollowerCount.oPromise.then($.proxy(channelFollowerCount.renderFollowerCount, '
#  'channelFollowerCount));\n'
#  '\n'
#  '\t\t\t\tvar incrementFollowerCount = function () {\n'
#  '\t\t\t\t\tchannelFollowerCount.incrementAndRenderFollowerCount();\n'
#  '\t\t\t\t};\n'
#  '\n'
#  '\t\t\t\tvar decrementFollowerCount = function () {\n'
#  '\t\t\t\t\tchannelFollowerCount.decrementAndRenderFollowerCount();\n'
#  '\t\t\t\t}\n'
#  '\t\t\t}\n'
#  '\n'
#  '\t\t\tif (isMillionBadgeVisible) {\n'
#  '\t\t\t\tchannelFollowerCount.oPromise.then(function (followerCount) {\n'
#  '\t\t\t\t\tvar nFollowerCount = followerCount || 0;\n'
#  '\t\t\t\t\tvar nFollowerCountInMillion = Math.floor(nFollowerCount / '
#  '1000000);\n'
#  '\t\t\t\t\tvar nFollowerCountInMan = nFollowerCountInMillion * 100;\n'
#  '\t\t\t\t\tif (nFollowerCountInMillion < 1) {\n'
#  '\t\t\t\t\t\tif (!isChannelFollowerVisible) {\n'
#  '\t\t\t\t\t\t\t$(".press_hd_subscribe").remove();\n'
#  '\t\t\t\t\t\t}\n'
#  '\t\t\t\t\t\treturn;\n'
#  '\t\t\t\t\t} else {\n'
#  "\t\t\t\t\t\tvar sMillionClassName = 'as_' + ((nFollowerCountInMillion % 10 "
#  "=== 0) ? 10 : nFollowerCountInMillion % 10) + 'million';\n"
#  '\n'
#  '\t\t\t\t\t\twelFollowerLabel.show();\n'
#  '\t\t\t\t\t\twelMillionBadgeArea.addClass(sMillionClassName)\n'
#  "\t\t\t\t\t\twelMillionBadgeArea.append(' <i "
#  'class="press_ico">구독자수</i><em>\' + nFollowerCountInMan + '
#  "'</em>만').show();\n"
#  '\t\t\t\t\t}\n'
#  '\t\t\t\t});\n'
#  '\t\t\t}\n'
#  '        }\n'
#  '        /* 채널구독수 */\n'
#  '\n'
#  '        /* 채널구독버튼 */\n'
#  '        var channelSubscribeButton = new '
#  "PressHomeMainManager.ChannelSubscribeButton('._press_hd_subscribe_btnwrap', "
#  '{\n'
#  '            officeId: officeId,\n'
#  "            buttonClassName: 'press_hd_subscribe_btn',\n"
#  '            noLoginLayerTemplate: function() {\n'
#  '            \treturn news.Util.getTemplateRenderer(function () '
#  '{/*!@preserve\n'
#  '            \t\t\t\t<div class="press_hd_subscribe_layer_wrap as_tooltip '
#  '_afterAdd" style="display: none;">\n'
#  '\t\t\t\t\t\t\t\t<div class="press_hd_subscribe_layer">\n'
#  '\t\t\t\t\t\t\t\t\t<p class="press_hd_subscribe_layer_title">메인 뉴스판에서 중앙일보 '
#  '주요뉴스를 볼 수 있습니다.</p>\n'
#  '\t\t\t\t\t\t\t\t\t<div class="press_hd_subscribe_layer_btns">\n'
#  '\t\t\t\t\t\t\t\t\t\t<a href="#" onclick="goMainChannelUrl();" '
#  'class="press_hd_subscribe_layer_btn">보러가기</a>\n'
#  '\t\t\t\t\t\t\t\t\t</div>\n'
#  '\t\t\t\t\t\t\t\t</div>\n'
#  '\t\t\t\t\t\t\t</div>\n'
#  '\t\t\t\t\t*/\n'
#  '\t\t\t\t\treturn true;\n'
#  '\t\t\t\t});\n'
#  '\t\t\t},\n'
#  '\t\t\tcommonLayerTemplate: function() {\n'
#  '            \treturn news.Util.getTemplateRenderer(function() {/*!@preserve\n'
#  '            \t\t\t\t<div class="press_hd_subscribe_layer_wrap as_tooltip '
#  '_afterRemove" style="display: none;">\n'
#  '\t\t\t\t\t\t\t\t<div class="press_hd_subscribe_layer">\n'
#  '\t\t\t\t\t\t\t\t\t<p '
#  'class="press_hd_subscribe_layer_title"><strong>중앙일보</strong> 언론사 구독 '
#  '해지되었습니다.</p>\n'
#  '\t\t\t\t\t\t\t\t</div>\n'
#  '\t\t\t\t\t\t\t</div>\n'
#  '            \t\t*/\n'
#  '\t\t\t\t\treturn true;\n'
#  '            \t});\n'
#  '\t\t\t},\n'
#  "            nclk_add: 'hom.take',\n"
#  "            nclk_remove: 'hom.cancel',\n"
#  "            nclk_info: 'hom.info',\n"
#  '            onAddChannelSuccess: incrementFollowerCount,\n'
#  '            onRemoveChannelSuccess: decrementFollowerCount,\n'
#  '\t\t\tneedNotificationButton: true,\n'
#  '\t\t\tneedNotificationConfirm: true\n'
#  '        });\n'
#  '        /* 채널구독버튼 */\n'
#  '\n'
#  '        /* 공유하기 */\n'
#  '\t\tif (!isLiveViewer && !isLiveUrl) {\n'
#  '\t\t\tinitShare();\n'
#  '\t\t}\n'
#  '        /* 공유하기 */\n'
#  '\n'
#  '        /* 뒤로버튼 */\n'
#  '        var historyBackButton = new '
#  "PressHomeMainManager.HistoryBackButton('._press_header ._back_btn');\n"
#  '        /* 뒤로버튼 */\n'
#  '\n'
#  '        /* 언론사리스트 */\n'
#  '\t\tif (!isLiveViewer && !isLiveUrl) {\n'
#  '\t\t\tvar pressListPopup = initPressList();\n'
#  '\t\t}\n'
#  '        /* 언론사리스트 */\n'
#  '\n'
#  '\t\treturn {\n'
#  '            channelFollowerCount: channelFollowerCount,\n'
#  '            historyBackButton: historyBackButton,\n'
#  '            channelSubscribeButton: channelSubscribeButton,\n'
#  '            pressListPopup: pressListPopup\n'
#  '        }\n'
#  '\t}\n'
#  '</script>\n'
#  '\n'
#  '<script>\n'
#  '\tvar profileData = null;\n'
#  '\tvar billboardChartLibUrl = '
#  "['https://ssl.pstatic.net/static.news/mnews/resources/20230906_104903/js/generated/billboard.pkgd.min.js'];\n"
#  '\n'
#  '    function initPressHomeTopLnb(params) {\n'
#  '        var pressHomeLnb = initPressHomeLnb();\n'
#  '\n'
#  "        var officeId = '025';\n"
#  "        var welOffceHomeTabList = $('._office_home_tab_list');\n"
#  "        var pressHeader = $('._press_header');\n"
#  '        var isTabPresent = welOffceHomeTabList.length > 0;\n'
#  '\n'
#  '        /* 플로팅 */\n'
#  '        var _floatingConfig = {\n'
#  "            sFixedContentSelector: '._fixed',\n"
#  '            onInitialize: function() {\n'
#  '                new '
#  "PressHomeMainManager.ChannelSubscribeButton('._press_float_subscribe', {\n"
#  '                    officeId: officeId,\n'
#  "                    buttonClassName: 'press_float_subscribe_btn',\n"
#  '\t\t\t\t\tnoLoginLayerTemplate: function() {\n'
#  '            \t\t\treturn news.Util.getTemplateRenderer(function () '
#  '{/*!@preserve\n'
#  '\t\t\t\t\t\t\t\t<a href="javascript:;" onclick="goMainChannelUrl();" '
#  'class="press_float_subscribe_layer _afterAdd" style="display: none;">\n'
#  '\t\t\t\t\t\t\t\t\t<span class="press_float_subscribe_layer_text">메인 뉴스판에서 '
#  '중앙일보 주요뉴스를 볼 수 있습니다.</span>\n'
#  '\t\t\t\t\t\t\t\t\t<span '
#  'class="press_float_subscribe_layer_link">보러가기</span>\n'
#  '\t\t\t\t\t\t\t\t</a>\n'
#  '\t\t\t\t\t\t\t\t*/\n'
#  '\t\t\t\t\t\t\treturn true;\n'
#  '\t\t\t\t\t\t});\n'
#  '\t\t\t\t\t},\n'
#  '\t\t\t\t\tcommonLayerTemplate: function() {\n'
#  '\t\t            \treturn news.Util.getTemplateRenderer(function() '
#  '{/*!@preserve\n'
#  '\t\t\t\t\t\t\t\t<a href="javascript:;" onclick="return false;" '
#  'class="press_float_subscribe_layer _afterRemove" style="display: none;">\n'
#  '\t\t\t\t\t\t\t\t\t<span '
#  'class="press_float_subscribe_layer_text"><strong>중앙일보</strong> 언론사 구독 '
#  '해지되었습니다.</span>\n'
#  '\t\t\t\t\t\t\t\t</a>\n'
#  '\t\t            \t\t\t*/\n'
#  '\t\t\t\t\t\t\treturn true;\n'
#  '\t\t\t\t\t\t});\n'
#  '\t\t\t\t\t},\n'
#  "                    nclk_add: 'prs_hom.take',\n"
#  "                    nclk_remove: 'prs_hom.cancel',\n"
#  "                    nclk_info: 'prs_hom.info',\n"
#  '                    onAddChannelSuccess: '
#  'pressHomeLnb.channelSubscribeButton.onAddChannelSuccess,\n'
#  '                    onRemoveChannelSuccess: '
#  'pressHomeLnb.channelSubscribeButton.onRemoveChannelSuccess\n'
#  '                });\n'
#  '            },\n'
#  '\t\t\tonStartFloating: function() {\n'
#  "\t\t\t\tpressHeader.addClass('is_invisible');\n"
#  '\t\t\t},\n'
#  '\t\t\tonStopFloating: function() {\n'
#  "\t\t\t\tpressHeader.removeClass('is_invisible');\n"
#  '\t\t\t}\n'
#  '        };\n'
#  '        if (isTabPresent) {\n'
#  '            _floatingConfig.fnBoundary = function(){\n'
#  '            \treturn $("._start_floating").offset().top - '
#  '$("._press_float").height();\n'
#  '            }\n'
#  '        } else {\n'
#  "            _floatingConfig.sAfterContentSelector = '._press_header';\n"
#  '        }\n'
#  "        var floating = new PressHomeMainManager.Floating('._press_float', "
#  '_floatingConfig);\n'
#  '        /* 플로팅 */\n'
#  '\n'
#  '        /* 뒤로버튼 */\n'
#  '        var historyBackButton = new '
#  "PressHomeMainManager.HistoryBackButton('._press_float ._back_btn');\n"
#  '        /* 뒤로버튼 */\n'
#  '\n'
#  '        return {\n'
#  '            floating: floating,\n'
#  '            pressHomeLnb: pressHomeLnb,\n'
#  '            historyBackButton: historyBackButton\n'
#  '        }\n'
#  '    }\n'
#  '</script>\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '<div class="press_float _press_float is_fixed" style="background-color: '
#  '#393a3c; display:none;">\n'
#  '\t<div class="press_float_inner">\n'
#  '\t\t<a href="javascript:;" class="press_float_prev _back_btn">이전</a>\n'
#  '\t\t<a href="https://www.naver.com" class="press_float_logo"><span '
#  'class="blind">NAVER</span></a>\n'
#  '\t\t<a href="https://news.naver.com/main" class="press_float_service ">\n'
#  '\t\t\t<span class="blind">뉴스</span>\n'
#  '\t\t</a>\n'
#  '\t\t<div class="press_float_head">\n'
#  '\t\t\t<strong class="press_float_title">\n'
#  '\t\t\t\t<a href="/press/025" class="press_float_title_text" '
#  'onclick="nclk(event,\'prs_hom.top\',025,\'\');">중앙일보</a>\n'
#  '\t\t\t</strong>\n'
#  '\t\t</div>\n'
#  '\n'
#  '\t\t<div class="press_float_subscribe _press_float_subscribe">\n'
#  '\t\t</div>\n'
#  '\n'
#  '\t</div>\n'
#  '</div>\n'
#  '<div id="ct" role="main" class="press _start_floating" '
#  'style="min-height:3000px;">\n'
#  '\t\n'
#  '\t\t\n'
#  '\t\t\t\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '<div class="press_section_tab _press_tab_scroll _fixed is_fixed" '
#  'style="display:none; background-color: #393a3c;">\n'
#  '\t<div class="press_section_tab_inner">\n'
#  '\t\t<ul class="press_section_tab_list _office_home_tab_list">\n'
#  '\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t<li class="press_section_tab_item " aria-selected="false">\n'
#  '\t\t\t\t\t<a href="/press/025" class="_press_tab_btn" '
#  'data-tab-type="Default" data-tab-id="Main">\n'
#  '\t\t\t\t\t\t<span class="press_section_tab_txt">주요뉴스</span>\n'
#  '\t\t\t\t\t</a>\n'
#  '\t\t\t\t</li>\n'
#  '\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t<li class="press_section_tab_item " aria-selected="false">\n'
#  '\t\t\t\t\t<a href="/press/025/shortform" class="_press_tab_btn" '
#  'data-tab-type="Link" data-tab-id="ShortForm">\n'
#  '\t\t\t\t\t\t<span class="press_section_tab_txt">숏폼</span>\n'
#  '\t\t\t\t\t</a>\n'
#  '\t\t\t\t</li>\n'
#  '\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t<li class="press_section_tab_item " aria-selected="false">\n'
#  '\t\t\t\t\t<a href="/press/025?sid=100" class="_press_tab_btn" '
#  'data-tab-type="Section" data-tab-id="Politics">\n'
#  '\t\t\t\t\t\t<span class="press_section_tab_txt">정치</span>\n'
#  '\t\t\t\t\t</a>\n'
#  '\t\t\t\t</li>\n'
#  '\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t<li class="press_section_tab_item " aria-selected="false">\n'
#  '\t\t\t\t\t<a href="/press/025?sid=101" class="_press_tab_btn" '
#  'data-tab-type="Section" data-tab-id="Economy">\n'
#  '\t\t\t\t\t\t<span class="press_section_tab_txt">경제</span>\n'
#  '\t\t\t\t\t</a>\n'
#  '\t\t\t\t</li>\n'
#  '\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t<li class="press_section_tab_item " aria-selected="false">\n'
#  '\t\t\t\t\t<a href="/press/025?sid=102" class="_press_tab_btn" '
#  'data-tab-type="Section" data-tab-id="Society">\n'
#  '\t\t\t\t\t\t<span class="press_section_tab_txt">사회</span>\n'
#  '\t\t\t\t\t</a>\n'
#  '\t\t\t\t</li>\n'
#  '\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t<li class="press_section_tab_item " aria-selected="false">\n'
#  '\t\t\t\t\t<a href="/press/025?sid=103" class="_press_tab_btn" '
#  'data-tab-type="Section" data-tab-id="LifeCulture">\n'
#  '\t\t\t\t\t\t<span class="press_section_tab_txt">생활</span>\n'
#  '\t\t\t\t\t</a>\n'
#  '\t\t\t\t</li>\n'
#  '\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t<li class="press_section_tab_item " aria-selected="false">\n'
#  '\t\t\t\t\t<a href="/press/025?sid=104" class="_press_tab_btn" '
#  'data-tab-type="Section" data-tab-id="World">\n'
#  '\t\t\t\t\t\t<span class="press_section_tab_txt">세계</span>\n'
#  '\t\t\t\t\t</a>\n'
#  '\t\t\t\t</li>\n'
#  '\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t<li class="press_section_tab_item " aria-selected="true">\n'
#  '\t\t\t\t\t<a href="/press/025?sid=105" class="_press_tab_btn" '
#  'data-tab-type="Section" data-tab-id="It">\n'
#  '\t\t\t\t\t\t<span class="press_section_tab_txt">IT</span>\n'
#  '\t\t\t\t\t</a>\n'
#  '\t\t\t\t</li>\n'
#  '\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\t\n'
#  '\t\t\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t<li class="press_section_tab_item " aria-selected="false">\n'
#  '\t\t\t\t\t<a href="/press/025?sid=110" class="_press_tab_btn" '
#  'data-tab-type="Section" data-tab-id="Opinion">\n'
#  '\t\t\t\t\t\t<span class="press_section_tab_txt">사설/칼럼</span>\n'
#  '\t\t\t\t\t</a>\n'
#  '\t\t\t\t</li>\n'
#  '\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t<li class="press_section_tab_item " aria-selected="false">\n'
#  '\t\t\t\t\t<a href="/press/025/newspaper" class="_press_tab_btn" '
#  'data-tab-type="Link" data-tab-id="Newspaper">\n'
#  '\t\t\t\t\t\t<span class="press_section_tab_txt">신문보기</span>\n'
#  '\t\t\t\t\t</a>\n'
#  '\t\t\t\t</li>\n'
#  '\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t\n'
#  '\t\t\t\t<li class="press_section_tab_item " aria-selected="false">\n'
#  '\t\t\t\t\t<a href="/press/025/ranking" class="_press_tab_btn" '
#  'data-tab-type="Default" data-tab-id="Ranking">\n'
#  '\t\t\t\t\t\t<span class="press_section_tab_txt">랭킹</span>\n'
#  '\t\t\t\t\t</a>\n'
#  '\t\t\t\t</li>\n'
#  '\t\t\t\n'
#  '\t\t</ul>\n'
#  '\t</div>\n'
#  '</div>\n'
#  '\n'
#  '<script>\n'
#  '    // NEW-23795\n'
#  '    function addTabClassIfNecessary() {\n'
#  "        var welTabScroll = $('._press_tab_scroll');\n"
#  '        if (welTabScroll.length > 0) {\n'
#  "            var welTabs = $('._office_home_tab_list').children();\n"
#  '            var welSelectedTab = '
#  "$('.press_section_tab_item[aria-selected=true]')\n"
#  '\n'
#  '            var nIndex = welTabs.index(welSelectedTab);\n'
#  "            welTabScroll.removeClass('is_first').removeClass('is_last');\n"
#  '            if (nIndex == 0) {\n'
#  "                welTabScroll.addClass('is_first');\n"
#  '            } else if (nIndex == welTabs.length - 1) {\n'
#  "                welTabScroll.addClass('is_last');\n"
#  '            }\n'
#  '        }\n'
#  '    }\n'
#  '\n'
#  '    function initPressHomeTab(params) {\n'
#  "        var officeId = '025';\n"
#  '\n'
#  '        /* 탭 */\n'
#  "        var welTabScroll = $('._press_tab_scroll');\n"
#  '        if (welTabScroll.length > 0) {\n'
#  '            // position 0 부터 시작한다. ("style 속성 자체를 지우면 스크롤이 적용되지 않는다" on '
#  'iOS)\n'
#  "            welTabScroll.children().eq(0).css('left', '0px');\n"
#  '            var pressTabScroll = new news.Scroll("._press_tab_scroll");\n'
#  '            // ._press_tab_scroll이 floating 상태에 따라 height값이 달라져 고정하지 않도록 설정\n'
#  '            $("._press_tab_scroll").css("height", ""); \n'
#  '            var welSelectedTab = '
#  "$('.press_section_tab_item[aria-selected=true]');\n"
#  '            if (welSelectedTab.length > 0) {\n'
#  '                pressTabScroll.scrollElToCenter(welSelectedTab);\n'
#  '            }\n'
#  '        }\n'
#  '        /* 탭 */\n'
#  '        addTabClassIfNecessary();\n'
#  '\n'
#  '        /* 섹션탭 클릭 */\n'
#  '        var pressTabButton = new '
#  "PressHomeMainManager.ButtonListener('._press_tab_btn', {\n"
#  '            onClick: function (e) {\n'
#  "                var tabType = $(e.currentTarget).data('tab-type');\n"
#  "\t\t\t\tvar tabId = $(e.currentTarget).data('tab-id');\n"
#  "                if (!(tabType === 'home' || tabType === 'link')) {\n"
#  '\t\t\t\t\tif (params && params.floating && params.floating.isFloating) {\n'
#  "\t\t\t\t\t\te.currentTarget.hash = 'lnb';\n"
#  '\t\t\t\t\t}\n'
#  '\t\t\t\t}\n'
#  "                if (tabId === 'Main') {\n"
#  "                    nclk(e, 'hom.mm', officeId, '');\n"
#  "                } else if (tabId === 'NaverTvLive') {\n"
#  "                    nclk(e, 'hom.live', officeId, '');\n"
#  "                } else if (tabId === 'Ranking') {\n"
#  "                \tnclk(e, 'hom.rank',officeId,'');\n"
#  "\t\t\t\t} else if (tabId === 'Premium') {\n"
#  "                    nclk(e, 'hom.premium', officeId, '');\n"
#  "\t\t\t\t} else if (tabId === 'ShortForm') {\n"
#  "\t\t\t\t\tnclk(e, 'hom.short', officeId, '');\n"
#  '\t\t\t\t} else {\n'
#  "\t\t\t\t\tnclk(e, 'hom.section', officeId, '');\n"
#  '\t\t\t\t}\n'
#  '            }\n'
#  '        });\n'
#  '        /* 섹션탭 클릭 */\n'
#  '\n'
#  '        return {\n'
#  '            pressTabScroll: pressTabScroll,\n'
#  '            pressTabButton: pressTabButton\n'
#  '\t\t}\n'
#  '    }\n'
#  '</script>\n'
#  '\n'
#  '<script>\n'
#  '    /**\n'
#  '     * `focus to lnb` 대응 (url format: `some/url#lnb`)\n'
#  '     */\n'
#  '    ;(function(){\n'
#  '        var isFocusToLnbMode = false;\n'
#  '\n'
#  '        // default 마크업 구성을 `focus to lnb` 로 하고 (floating lnb 로 구성),\n'
#  '        // `focus to lnb` 접근이 아닐 경우 `floating lnb` 구성을 해제하는 컨셉. (to static '
#  '으로)\n'
#  '        //\n'
#  '        // default 마크업 구성을 `floating lnb` 로 한 이유:\n'
#  '        // 1. `static lnb` 방식으로 하면,\n'
#  '        // 2. `focus` 처리할 때 "화면 덜컹 거림이 보여서" 보기 좋지 않다.\n'
#  '        //\n'
#  '        // `focus` 요청일 경우,\n'
#  '        // 필요한 추가 처리는 content 출력 후 처리돼있다. (e.g. scroll 이동)\n'
#  "        if(location.hash === '#lnb'){\n"
#  '            isFocusToLnbMode = true;\n'
#  '        }\n'
#  '\n'
#  '        // "뒤로가기", "새로고침" 일 경우 focus 처리하지 않는다. (browser 에서 scroll 자동 이동 '
#  '시키므로)\n'
#  '        (function () {\n'
#  '            var winNavigation = (window.performance && '
#  'window.performance.navigation) || {};\n'
#  '            var isReload = winNavigation.type === '
#  'winNavigation.TYPE_RELOAD;\n'
#  '            var isHistoryBack = winNavigation.type === '
#  'winNavigation.TYPE_BACK_FORWARD;\n'
#  '            // 상수를 지원하지 않을 경우도 focus 처리하지 않음\n'
#  '            if(isHistoryBack || isReload || '
#  '!winNavigation.TYPE_BACK_FORWARD){\n'
#  '                isFocusToLnbMode = false;\n'
#  '            }\n'
#  '        })();\n'
#  '\n'
#  '        try{\n'
#  "            // 서버 기본 설정이 `lnb floating + block' 이면 LNB 움직이는게 보여서 script 에서 "
#  'block 되도록 했다.\n'
#  "            document.querySelector('._press_float').style.display = '';\n"
#  "            document.querySelector('._press_tab_scroll').style.display = "
#  "'';\n"
#  '        }catch(e){}\n'
#  '\n'
#  '        // 선택된 LNB 중앙 정렬 선처리 (onload 후 Scroll-UI 에서 중앙 정렬시 이동이 보이지 않게)\n'
#  '        (function(){\n'
#  '            try{\n'
#  "                var lnb = document.querySelector('._press_tab_scroll');\n"
#  '                var lnbScrollContent = lnb.firstElementChild;\n'
#  '                var selectedItem = '
#  'lnb.querySelector(\'li[aria-selected="true"]\');\n'
#  '                var maxScrollLeft = 0;\n'
#  '                var selectedItemScrollLeft = 0;\n'
#  '\n'
#  '                // Scroll-UI 적용 전에 inline style 은 제거해 줘야 한다. (e.g. onload 후 '
#  '적용 될 때)\n'
#  "                lnbScrollContent.style.position = 'absolute';\n"
#  '                maxScrollLeft = lnbScrollContent.clientWidth - '
#  'lnb.clientWidth;\n'
#  '                if(maxScrollLeft <= 0){ // lnb 가 content 보다 크다. (scroll 필요 '
#  '없는 경우)\n'
#  '                    return;\n'
#  '                }\n'
#  '                selectedItemScrollLeft = Math.max(\n'
#  '                    0,\n'
#  '                    (selectedItem.offsetLeft || 0) -\n'
#  '                    ((lnb.clientWidth - selectedItem.clientWidth) / 2)\n'
#  '                );\n'
#  '                selectedItemScrollLeft = Math.min(maxScrollLeft, '
#  'selectedItemScrollLeft);\n'
#  '                lnbScrollContent.style.left = -1 * '
#  "Math.round(selectedItemScrollLeft) + 'px';\n"
#  '            }catch(e){}\n'
#  '        })();\n'
#  '\n'
#  '        // 1. focus mode 라면 서버 출력 마크업을 그대로 두고\n'
#  '        // 2. 이후 처리는 content 출력 후 js 에서 하는 구조다.\n'
#  '        if(isFocusToLnbMode){\n'
#  '            return;\n'
#  '        }\n'
#  '\n'
#  '        /**\n'
#  '         * `focus to lnb` 접근이 아니라면 `static lnb` 구성으로 마크업 변경\n'
#  '         */\n'
#  '        try{\n'
#  "            var header = document.querySelector('._press_header');\n"
#  "            var headerFloat = document.querySelector('._press_float');\n"
#  "            var lnb = document.querySelector('._press_tab_scroll');\n"
#  '\n'
#  "            header.style.display = '';\n"
#  '            headerFloat.className = '
#  "headerFloat.className.replace('is_fixed', '');\n"
#  '            if(lnb){\n'
#  "                lnb.className = lnb.className.replace('is_fixed', '');\n"
#  '            }\n'
#  '        }catch(e){}\n'
#  '    })();\n'
#  '</script>\n'
#  '\n'
#  '\t\t\n'
#  '\t\t\n'
#  '\t\n'
#  '\t<script>\n'
#  '\t\t/**\n'
#  '\t\t * `focus to lnb` 대응 (content 출력 후 추가 처리)\n'
#  '\t\t */\n'
#  '\t\t;(function () {\n'
#  '\t\t\ttry {\n'
#  "\t\t\t\tvar startFloating = document.querySelector('._start_floating');\n"
#  "\t\t\t\tvar header = document.querySelector('._press_header');\n"
#  '\t\t\t\tvar lnbScrollPaddingTop = '
#  "document.querySelector('._press_float').clientHeight;\n"
#  '\n'
#  '\t\t\t\t// js 처리 관련 inline style 제거\n'
#  "\t\t\t\twindow.addEventListener('load', function () {\n"
#  "\t\t\t\t\tdocument.querySelector('#ct').style.minHeight = '';\n"
#  '\t\t\t\t});\n'
#  '\n'
#  '\t\t\t\t// display none 상태가 아니면 `focus to lnb` 접근이 아니다.\n'
#  "\t\t\t\tif (header.style.display !== 'none') {\n"
#  '\t\t\t\t\treturn;\n'
#  '\t\t\t\t}\n'
#  "\t\t\t\theader.style.display = ''; // show header\n"
#  '\t\t\t\t\n'
#  '\t\t\t\tvar floatingOffset = startFloating.getBoundingClientRect().top + '
#  'window.pageYOffset;\n'
#  '\t\t\t\twindow.scrollTo(0, floatingOffset - lnbScrollPaddingTop);\n'
#  '\t\t\t}catch(e){}\n'
#  '\t\t})();\n'
#  '\t</script>\n'
#  '\n'
#  '\n'
#  '    \n'
#  '<div class="_tab_panel" data-section-id="105" data-section-lnb-id="It" '
#  'data-office-id="025">\n'
#  '    \n'
#  '        \n'
#  '        <div class="press_edit_news">\n'
#  '            <ul class="press_edit_news_list as_5item_separator">\n'
#  '        \n'
#  '                \n'
#  '                <li class="press_edit_news_item as_thumb _rcount" '
#  'data-comment=\'{"gno":"news025,0003307582","type":"press","queryUrl":"sid=105"}\' '
#  'data-service-datetime="2023091317100000000">\n'
#  '                    <a '
#  'href="https://n.news.naver.com/article/025/0003307582?sid=105" '
#  'class="press_edit_news_link _es_pc_link" data-pc-link="">\n'
#  '                        \n'
#  '                            <span class="press_edit_news_thumb">\n'
#  '                                <img '
#  'src="https://mimgnews.pstatic.net/image/origin/025/2023/09/13/3307582.jpg?type=nf212_140&ut=1694592600000" '
#  'width="106" height="70" alt="" onerror="showNoImage(this)" >\n'
#  '                                \n'
#  '                            </span>\n'
#  '                        \n'
#  '                        <span class="press_edit_news_text">\n'
#  '                            <span class="press_edit_news_title">경주시, ‘해오름동맹’ '
#  '벤처·창업기업 혁신포럼 개최</span>\n'
#  '                            <span class="r_ico_b r_modify '
#  '"><b>9분전</b></span>\n'
#  '                        </span>\n'
#  '                    </a>\n'
#  '                </li>\n'
#  '        \n'
#  '    \n'
#  '        \n'
#  '                \n'
#  '                <li class="press_edit_news_item as_thumb _rcount" '
#  'data-comment=\'{"gno":"news025,0003307553","type":"press","queryUrl":"sid=105"}\' '
#  'data-service-datetime="2023091315512100000">\n'
#  '                    <a '
#  'href="https://n.news.naver.com/article/025/0003307553?sid=105" '
#  'class="press_edit_news_link _es_pc_link" data-pc-link="">\n'
#  '                        \n'
#  '                            <span class="press_edit_news_thumb">\n'
#  '                                <img '
#  'src="https://mimgnews.pstatic.net/image/origin/025/2023/09/13/3307553.jpg?type=nf212_140&ut=1694587881000" '
#  'width="106" height="70" alt="" onerror="showNoImage(this)" >\n'
#  '                                \n'
#  '                            </span>\n'
#  '                        \n'
#  '                        <span class="press_edit_news_text">\n'
#  '                            <span class="press_edit_news_title">[팩플] “AI 가장 '
#  '잘 활용하는 국가로”…‘AI 일상화 계획’, 성공 조건은</span>\n'
#  '                            <span class="r_ico_b r_modify '
#  'is_outdated"><b>1시간전</b></span>\n'
#  '                        </span>\n'
#  '                    </a>\n'
#  '                </li>\n'
#  '        \n'
#  '    \n'
#  '        \n'
#  '                \n'
#  '                <li class="press_edit_news_item as_thumb _rcount" '
#  'data-comment=\'{"gno":"news025,0003307498","type":"press","queryUrl":"sid=105"}\' '
#  'data-service-datetime="2023091311350000000">\n'
#  '                    <a '
#  'href="https://n.news.naver.com/article/025/0003307498?sid=105" '
#  'class="press_edit_news_link _es_pc_link" data-pc-link="">\n'
#  '                        \n'
#  '                            <span class="press_edit_news_thumb">\n'
#  '                                <img '
#  'src="..." '
#  'data-src="https://mimgnews.pstatic.net/image/origin/025/2023/09/13/3307498.jpg?type=nf212_140&ut=1694572500000" '
#  'width="106" height="70" alt="" onerror="showNoImage(this)" >\n'
#  '                                \n'
#  '                            </span>\n'
#  '                        \n'
#  '                        <span class="press_edit_news_text">\n'
#  '                            <span class="press_edit_news_title">KENTECH, 극성 '
#  '산화물 표면 안정화 메커니즘 규명</span>\n'
#  '                            <span class="r_ico_b r_modify '
#  'is_outdated"><b>5시간전</b></span>\n'
#  '                        </span>\n'
#  '                    </a>\n'
#  '                </li>\n'
#  '        \n'
#  '    \n'
#  '        \n'
#  '                \n'
#  '                <li class="press_edit_news_item as_thumb _rcount" '
#  'data-comment=\'{"gno":"news025,0003307490","type":"press","queryUrl":"sid=105"}\' '
#  'data-service-datetime="2023091311050000000">\n'
#  '                    <a '
#  'href="https://n.news.naver.com/article/025/0003307490?sid=105" '
#  'class="press_edit_news_link _es_pc_link" data-pc-link="">\n'
#  '                        \n'
#  '                            <span class="press_edit_news_thumb">\n'
#  '                                <img '
#  'src="..." '
#  'data-src="https://mimgnews.pstatic.net/image/origin/025/2023/09/13/3307490.jpg?type=nf212_140&ut=1694570700000" '
#  'width="106" height="70" alt="" onerror="showNoImage(this)" >\n'
#  '                                \n'
#  '                            </span>\n'
#  '                        \n'
#  '                        <span class="press_edit_news_text">\n'
#  '                            <span class="press_edit_news_title">KIST, '
#  '美로렌스리버모어 국립연구소와 공동 워크숍 개최</span>\n'
#  '                            <span class="r_ico_b r_modify '
#  'is_outdated"><b>6시간전</b></span>\n'
#  '                        </span>\n'
#  '                    </a>\n'
#  '                </li>\n'
#  '        \n'
#  '    \n'
#  '        \n'
#  '                \n'
# ...
#  'data-comment=\'{"gno":"news025,0003306964","type":"press","queryUrl":"sid=105"}\' '
#  'data-service-datetime="2023091116500000000">\n'
#  '                    <a '
#  'href="https://n.news.naver.com/article/025/0003306964?sid=105" '
#  'class="press_edit_news_link _es_pc_link" data-pc-link="">\n'
#  '                        \n'
#  '                            <span class="press_edit_news_thumb">\n'
#  '                                <img '
#  'src="..." '
#  'data-src="https://mimgnews.pstatic.net/image/origin/025/2023/09/11/3306964.jpg?type=nf212_140&ut=1694418600000" '
#  'width="106" height="70" alt="" onerror="showNoImage(this)" >\n'
#  '                                \n'
#  '                            </span>\n'
#  '                        \n'
#  '                        <span class="press_edit_news_text">\n'
#  '                            <span class="press_edit_news_title">LG이노텍 x '
#  '서울창조경제혁신센터 2023 스타트업 테크 블레이즈 개최</span>\n'
#  '                            <span class="r_ico_b r_modify '
#  'is_outdated"><b>2일전</b></span>\n'
#  '                        </span>\n'
#  '                    </a>\n'
#  '                </li>\n'
#  '        \n'
#  '            </ul>\n'
#  '        </div>\n'
#  '        \n'
#  '    \n'
#  '    <div class="r_more r_more_load _load_more_section_article">\n'
#  '        <div class="r_more_loader">\n'
#  '            \n'
#  '<div class="r_more_loading_icon">\n'
#  '\t<i class="r_more_dot as_1"></i>\n'
#  '\t<i class="r_more_dot as_2"></i>\n'
#  '\t<i class="r_more_dot as_3"></i>\n'
#  '\t<i class="r_more_dot as_4"></i>\n'
#  '\t<i class="r_more_dot as_5"></i>\n'
#  '\t<i class="r_more_dot as_6"></i>\n'
#  '</div>\n'
#  '        </div>\n'
#  '    </div>\n'
#  '</div>\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '<div class="press_desc_wrap">\n'
#  '\t\n'
#  '\t\t\n'
#  '\t\t\t<div class="press_desc"><em>중앙일보</em>의 최신 뉴스입니다.</div>\n'
#  '\t\t\n'
#  '\t\t\n'
#  '\t\t\n'
#  '\t\n'
#  '</div>\n'
#  '<p class="subscribe_ticker" style="display: none;">구독한 뉴스는 <em>My뉴스</em>에서 볼 '
#  '수 있습니다.</p>\n'
#  '\n'
#  '    </section>\n'
#  '\n'
#  '<section class="press_aside _aside_wrapper">\n'
#  '    <div class="press_aside_inner _aside_content">\n'
#  '        <h3 class="blind">구독</h3>\n'
#  '        <div class="_aside"></div> \n'
#  '<script>\n'
#  'doAfterLoadEnd(loadAside);\n'
#  '\n'
#  '\n'
#  'function loadAside() {\n'
#  '    var forcePcVersion = "";\n'
#  '\n'
#  '    if (isMobileDevice() && !forcePcVersion) {\n'
#  '        return;\n'
#  '    }\n'
#  '    var iframe = append(); \n'
#  '    var asideFixed;\n'
#  '\n'
#  "    window.addEventListener('message', function(event) {\n"
#  '        var data = event.data;\n'
#  '\n'
#  '        if (event.origin !== "https://news.naver.com") {  \n'
#  '            return;\n'
#  '        }\n'
#  '\n'
#  '        if (data.type === "setIframeSize" && data.height) {\n'
#  "            iframe.style.height = data.height + 'px';\n"
#  '            iframe.style.visibility = ""; \n'
#  '\n'
#  '            try {\n'
#  '                asideFixed.deactivate(); // event 중복 적용되지 않게\n'
#  '            } catch(e) {}\n'
#  '\n'
#  '            asideFixed = AsideFixed({\n'
#  '                "wrapper" : document.querySelector("._aside_wrapper")\n'
#  '                \n'
#  '            });\n'
#  '        }\n'
#  '    });\n'
#  '    \n'
#  '    \n'
#  '    function append() {\n'
#  "        var iframe = document.createElement('iframe');\n"
#  '\n'
#  '        iframe.width = "100%";\n'
#  '        iframe.height = "0"; \n'
#  '        iframe.style.visibility = "hidden"; \n'
#  '        iframe.setAttribute("frameborder", "no");\n'
#  '        iframe.setAttribute("scrolling", "no");\n'
#  '        iframe.src = "https://news.naver.com/aside?oid=025";\n'
#  '\n'
#  '        document.querySelector("._aside").appendChild(iframe);\n'
#  '\n'
#  '        return iframe;\n'
#  '    }\n'
#  '}\n'
#  '</script>\n'
#  '    </div>\n'
#  '</section>\n'
#  '</div>\n'
#  '</div>\n'
#  '\n'
#  '\n'
#  '\n'
#  '    \n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '<hr /> \n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '\n'
#  '<div class="mp_footer">\n'
#  '\n'
#  '    <div class="f_maininfo">\n'
#  '        <div class="f_maininfoinner">\n'
#  '            <a href="javascript:;" class="r_pg_top _go_top" id="goTop" '
#  'onclick="nclk(event, \'fot.pctop\', \'\', \'\');">맨위로</a>\n'
#  '\n'
#  '            <footer role="contentinfo">\n'
#  '                <p id="u_ftlkw" class="u_ftlkw _footer_login">\n'
#  '                    <a href="https://m.naver.com/services.html"  '
#  'data-mpurl=\'{"m":"https://m.naver.com/services.html","p":"https://www.naver.com/more.html"}\' '
#  'class="u_ftlk" '
#  'onclick="nclk(event,\'fot.serviceall\',\'\',\'\');">전체서비스</a>\n'
#  '                </p>\n'
#  '                <p class="u_cr">\n'
#  '                    <span class="u_ftm">\n'
#  '            \n'
#  '                \n'
#  '                    <span class="u_cri u_cri_v1"><a '
#  'href="https://m.news.naver.com/ombudsman/index" '
#  'data-mpurl=\'{"m":"https://m.news.naver.com/ombudsman/index","p":"https://news.naver.com/main/ombudsman/index.naver"}\' '
#  'class="u_cra" '
#  'onclick="nclk(event,\'fot.guide\',\'\',\'\');">서비스안내</a></span>\n'
#  '                    <span class="u_cri u_cri_v1"><a '
#  'href="https://help.naver.com/alias/news/news_007.naver" '
#  'data-mpurl=\'{"m":"https://help.naver.com/alias/news/news_007.naver","p":"https://help.naver.com/alias/news/news_007.naver"}\' '
#  'class="u_cra" '
#  'onclick="nclk(event,\'fot.help\',\'\',\'\');">뉴스도움말</a></span>\n'
#  '                    <span class="u_cri u_cri_v1"><a '
#  'href="https://help.naver.com/alias/news/news_001.naver" '
#  'data-mpurl=\'{"m":"https://help.naver.com/alias/news/news_001.naver","p":"https://help.naver.com/alias/news/news_001.naver"}\' '
#  'class="u_cra" '
#  'onclick="nclk(event,\'fot.report\',\'\',\'\');">오류신고</a></span>\n'
#  '                \n'
#  '                \n'
#  '            \n'
#  '\t\t\t\t\t</span>\n'
#  '            \n'
#  '                \n'
#  '                    <span class="u_copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며, '
#  '이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</span>\n'
#  '                    <span class="u_cri"><span class="copymark">ⓒ</span><a '
#  'href="https://www.navercorp.com/" class="u_cra_v1" id="nhnLink" '
#  'onclick="nclk(event,\'fot.navercorp\',\'\',\'\');">NAVER Corp.</a></span>\n'
#  '                    \n'
#  '                        \n'
#  '                            \n'
#  '                        \n'
#  '                        \n'
#  '                        \n'
#  '                    \n'
#  '                    \n'
#  '                        <span class="u_cri"><span class="copymark">ⓒ</span> '
#  '<a class="u_cra_v1" id="copyRightByOffice">중앙일보</a></span>\n'
#  '                    \n'
#  '                \n'
#  '                \n'
#  '            \n'
#  '                </p>\n'
#  '            </footer>\n'
#  '        </div>\n'
#  '    </div>\n'
#  '</div>\n'
#  '\n'
#  '\n'
#  '    \n'
#  '\t\n'
#  '\t\n'
#  '\t\t\n'
#  '\t\t\n'
#  '\t\n'
#  '\t\n'
#  '\t\n'
#  '    \n'
#  '    <script type="text/javascript">\n'
#  '/**\n'
#  ' * 이 파일은 모바일 뉴스 서비스 전체 페이지에 적용되는 스크립트로써,\n'
#  ' * 코드 추가 시 Front-End 성능 관점에서 주의를 요합니다.\n'
#  ' */\n'
#  "jQuery(window).on('load', function(){\n"
#  '    setTimeout(onload, 10);\n'
#  '\n'
#  '    function onload(){\n'
#  "        var oLnb = new news.Lnb('._lnb_scroll');\n"
#  '        new news.ImageLazyLoader().load("img[data-src]");\n'
#  '        new news.MoveTopButton("._go_top");\n'
#  '\n'
#  '        \n'
#  '        new news.HistoryManager().init("naver_mobile_news_history", "");\n'
#  '\n'
#  '        // iframe lazy-loading\n'
#  '        (function(){\n'
#  '            try {\n'
#  '                '
#  "Array.prototype.slice.apply(document.querySelectorAll('iframe[data-src]'))\n"
#  '                    .forEach(function(iframeEl) {\n'
#  "                        var originSrc = iframeEl.getAttribute('data-src');\n"
#  '                        if(originSrc) {\n'
#  "                            iframeEl.setAttribute('src', originSrc);\n"
#  '                        }\n'
#  '                    });\n'
#  '            }catch(e) {}\n'
#  '        })();\n'
#  '\n'
#  '        if(typeof init === "function"){\n'
#  '            init();\n'
#  '        }\n'
#  '\n'
#  '        var cookie = news.Cookie.getInstance();\n'
#  '        var isShownNewLnb = cookie.getItem("isShownNewLnb");\n'
#  '        if(isShownNewLnb == null) {\n'
#  '            isShownNewLnb = "Y";\n'
#  '            cookie.setItem("isShownNewLnb", isShownNewLnb, 3650, "", "/");\n'
#  '            $("._isNew").addClass("is_new");\n'
#  '        }\n'
#  '\n'
#  '        {\n'
#  "            var footerLogin = jQuery(document).find('._footer_login');\n"
#  '            if(footerLogin <= 0) {\n'
#  '                return;\n'
#  '            }\n'
#  '\n'
#  '            // 디바이스에 따라 로그인, 로그아웃 URL 분기\n'
#  '            var loginUrl = "https://nid.naver.com/nidlogin.login";\n'
#  '            var logoutUrl = "https://nid.naver.com/nidlogin.logout?";\n'
#  '            if (news.Util.getAgentInfo().bMobileOrTablet) {\n'
#  '                loginUrl = '
#  '"https://nid.naver.com/nidlogin.login?svctype=262144";\n'
#  '                logoutUrl = '
#  '"https://nid.naver.com/nidlogin.logout?svctype=262144&";\n'
#  '            }\n'
#  '\n'
#  '            if(news.LoginAssistor.isLoginUser()) {\n'
#  "                footerLogin.prepend('<a "
#  'href="javascript:news.Util.logout(\\\'\'+logoutUrl+\'url=\\\'+encodeURIComponent(location.href));" '
#  'class="u_ftlk" id="news_logout" '
#  'onclick="nclk(event,\\\'fot.logout\\\',\\\'\\\',\\\'\\\');" >로그아웃</a>\')\n'
#  '            }else {\n'
#  '                footerLogin.prepend(\'<a href="\'+loginUrl+\'" '
#  'class="u_ftlk" id="news_login" '
#  'onclick="nclk(event,\\\'fot.login\\\',\\\'\\\',\\\'\\\');" >로그인</a>\')\n'
#  '            }\n'
#  '        }\n'
#  '    }\n'
#  '});\n'
#  '</script>\n'
#  '\n'
#  '\n'
#  '\n'
#  '    \n'
#  '    \n'
#  '    \t<script>\n'
#  '    function init() {\n'
#  '        /* LNB */\n'
#  '        var pressHomeTopLnb = initPressHomeTopLnb();\n'
#  '        /* LNB */\n'
#  '\n'
#  '        /* 탭 */\n'
#  '        var pressHomeTab = initPressHomeTab({\n'
#  '            floating: pressHomeTopLnb.floating\n'
#  '        });\n'
#  '        /* 탭 */\n'
#  '\n'
#  '        /* 댓글 카운트 */\n'
#  '        news.CommentCountPainterToList.getInstance().renderCommentCount({\n'
#  '            linkDomainMap: {\n'
#  "                press: 'https://n.news.naver.com',\n"
#  "                pressHomeCard: 'https://n.news.naver.com'\n"
#  '            },\n'
#  '            addStyle: "prepend",\n'
#  '        });\n'
#  '        /* 댓글 카운트 */\n'
#  '\n'
#  '        /* 더보기 */\n'
#  "        new PressHomeMainManager.MoreSectionArticle('._tab_panel', {\n"
#  "            sDomain: 'https://n.news.naver.com',\n"
#  "            sCommentLinkDomain: 'https://n.news.naver.com'\n"
#  '        });\n'
#  '        /* 더보기 */\n'
#  '\n'
#  '        // 연/스 pc 기사링크 변경 대응\n'
#  '        PressHomeMainManager.EnterSportsLinkChanger();\n'
#  '\n'
#  '        new news.PressHomeProfile()\n'
#  '            .init({\n'
#  '                billboardChartLibUrl: billboardChartLibUrl,\n'
#  '                templateData: profileData\n'
#  '            })\n'
#  "            .on('toggleProfile', function(){\n"
#  '                pressHomeTopLnb.floating.updateBoundary();\n'
#  '            });\n'
#  '\n'
#  '        new news.ChannelPlugin()\n'
#  '            .init({\n'
#  '                channelPluginApiDomain: '
#  '"https://api.channel-plugin.naver.com",\n'
#  '                followLayerAutoCloseMs: 5000,\n'
#  "                nclickPrefix: 'prs_hom'\n"
#  '            });\n'
#  '\n'
#  '        var showSectionToggle = false;\n'
#  '        if (showSectionToggle) {\n'
#  "            $('#ps_toggle').bind('change', function() {\n"
#  '                var url = location.pathname;\n'
#  "                var sid = '105';\n"
#  '                var elToggle = $(this);\n'
#  "                var isChecked = elToggle.is(':checked');\n"
#  '                if (isChecked) {\n'
#  "                    window.location.href = url + '?sid=' + sid + "
#  "'&isSectionGroup=false'\n"
#  '                } else {\n'
#  "                    window.location.href = url + '?sid=' + sid + "
#  "'&isSectionGroup=true'\n"
#  '                }\n'
#  '            });\n'
#  '        }\n'
#  '    }\n'
#  "    var persistKey = 'pressHomeContents';\n"
#  '    var articleListDom = $.persist(persistKey);\n'
#  '    if (articleListDom) {\n'
#  "        $('._tab_panel').html(articleListDom);\n"
#  '    }\n'
#  '\n'
#  "    $(document).on('click', 'a', function(){\n"
#  "        $.persist(persistKey, $('._tab_panel').html());\n"
#  '    });\n'
#  '</script>\n'
#  '\n'
#  '    \n'
#  '\n'
#  '\t<script>\n'
#  "    var gnb_service = 'news';\n"
#  '    var gnb_logout = encodeURIComponent(location.href);\n'
#  "    var gnb_template = 'gnb_utf8';\n"
#  '    var gnb_brightness = 1;\n'
#  '    var gnb_item_hide_option= 128; \n'
#  '\n'
#  '    doAfterLoadEnd(function () {\n'
#  '        try {\n'
#  '            GlobalMPUrlManager.init();\n'
#  '        } catch (e) {}\n'
#  '    });\n'
#  '\n'
#  '    doAfterLoadEnd(function() {\n'
#  "        if (!document.querySelector('#gnb') || isMobileDevice() === true) "
#  '{ \n'
#  '            return;\n'
#  '        }\n'
#  '        \n'
#  '        var gnb_src = '
#  '"https://ssl.pstatic.net/static.gn/templates/gnb_utf8?2023091317";\n'
#  '\n'
#  '        // GnbHelper를 이용하여 GNB Layer를 닫을 수 있도록 지원한다.\n'
#  '        if (window.jindo) {\n'
#  '            jindo.LazyLoading.load(\n'
#  '                gnb_src,\n'
#  '                function() {\n'
#  '                    try {\n'
#  '                        getGNB();\n'
#  '                    } catch(e) {}\n'
#  '                },\n'
#  "                'utf-8'\n"
#  '            );\n'
#  '\n'
#  '            jindo.$Fn(function (oEvent) {\n'
#  '                \n'
#  '                GnbHelper.attachClick(oEvent.$value().target);\n'
#  "            }).attach(document, 'click');\n"
#  '        } else if (window.jQuery) {\n'
#  '            new news.JsLoader().\n'
#  '                load(\n'
#  '                    [gnb_src],\n'
#  '                    function() {\n'
#  '                        try {\n'
#  '                            getGNB();\n'
#  '                        } catch(e) {}\n'
#  '                    }\n'
#  '                );\n'
#  '\n'
#  '            $(document).on("click", function(event) {\n'
#  '                GnbHelper.attachClick(event.target);\n'
#  '            });\n'
#  '        }\n'
#  '    });\n'
#  '</script>\n'
#  '\n'
#  '<script>\n'
#  'doAfterLoadEnd(function() {\n'
#  '    try {\n'
#  '        new SearchAutoComplete({\n'
#  '            content: document.querySelector("._search_content"),\n'
#  '            contentToggleBtn: '
#  'document.querySelector("._search_content_toggle_btn"),\n'
#  '            isMobile: isMobileDevice(),\n'
#  '            nClickType: "newsM"\n'
#  '        });\n'
#  '    } catch(e) {}\n'
#  '});\n'
#  '</script>\n'
#  '\t<!-- LCS -->\n'
#  '\t\n'
#  '\n'
#  '\n'
#  '\n'
#  '<script type="text/javascript">\n'
#  '\n'
#  'function initMa(){\n'
#  '    var data = {\n'
#  '        "service": "news",\n'
#  '        "baseInfo": {\n'
#  '            "category": (function(){\n'
#  '                \n'
#  '                var result = "언론사홈";\n'
#  '\n'
#  '                if(result !== ""){\n'
#  '                    return result;\n'
#  '                }\n'
#  '                try{\n'
#  '                    \n'
#  '                    return '
#  'document.querySelector(\'meta[property="og:title"]\')\n'
#  "                        .getAttribute('content')\n"
#  "                        .replace(/[\\s]*:+[\\s]*네이버[\\s]*뉴스/, '');\n"
#  '                }catch(e){\n'
#  '                    return "";\n'
#  '                }\n'
#  '            })()\n'
#  '        },\n'
#  '        "extraInfo": {}\n'
#  '    };\n'
#  '\n'
#  '    \n'
#  '    data.extraInfo.sectionId = "" || "105";\n'
#  '    \n'
#  '    data.extraInfo.officeId = "025";\n'
#  '    \n'
#  '\n'
#  '    try{\n'
#  '        ma.init({\n'
#  '            api: "https://ma.news.naver.com/l",\n'
#  '            data: data\n'
#  '        });\n'
#  '    }catch(e){}\n'
#  '}\n'
#  '</script>\n'
#  '\n'
#  '\n'
#  '<script type="text/javascript">\n'
#  '\n'
#  '\n'
#  '\n'
#  'var eventType = "onpageshow" in window ? "pageshow" : "load";\n'
#  'jQuery(window).on(eventType, function() {\n'
#  '\n'
#  '\n'
#  '\n'
#  'lcs_do();\n'
#  '\n'
#  '\n'
#  '    try{\n'
#  '        initMa();\n'
#  '    }catch(e){}\n'
#  '});\n'
#  '</script>\n'
#  '\n'
#  '\n'
#  '\n'
#  '\t<!-- //LCS -->\n'
#  '</body>\n'
#  '</html>\n')

# %%
soup = bs(html.text, 'html.parser')

# %%
data1 = soup.find('div',{'class':'_tab_panel'})
pprint(data1)
# Out:
# <div class="_tab_panel" data-office-id="025" data-section-id="105" data-section-lnb-id="It">
# <div class="press_edit_news">
# <ul class="press_edit_news_list as_5item_separator">
# <li class="press_edit_news_item as_thumb _rcount" data-comment='{"gno":"news025,0003307582","type":"press","queryUrl":"sid=105"}' data-service-datetime="2023091317100000000">
# <a class="press_edit_news_link _es_pc_link" data-pc-link="" href="https://n.news.naver.com/article/025/0003307582?sid=105">
# <span class="press_edit_news_thumb">
# <img alt="" height="70" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/025/2023/09/13/3307582.jpg?type=nf212_140&amp;ut=1694592600000" width="106"/>
# </span>
# <span class="press_edit_news_text">
# <span class="press_edit_news_title">경주시, ‘해오름동맹’ 벤처·창업기업 혁신포럼 개최</span>
# <span class="r_ico_b r_modify"><b>9분전</b></span>
# </span>
# </a>
# </li>
# <li class="press_edit_news_item as_thumb _rcount" data-comment='{"gno":"news025,0003307553","type":"press","queryUrl":"sid=105"}' data-service-datetime="2023091315512100000">
# <a class="press_edit_news_link _es_pc_link" data-pc-link="" href="https://n.news.naver.com/article/025/0003307553?sid=105">
# <span class="press_edit_news_thumb">
# <img alt="" height="70" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/025/2023/09/13/3307553.jpg?type=nf212_140&amp;ut=1694587881000" width="106"/>
# </span>
# <span class="press_edit_news_text">
# <span class="press_edit_news_title">[팩플] “AI 가장 잘 활용하는 국가로”…‘AI 일상화 계획’, 성공 조건은</span>
# <span class="r_ico_b r_modify is_outdated"><b>1시간전</b></span>
# </span>
# </a>
# </li>
# <li class="press_edit_news_item as_thumb _rcount" data-comment='{"gno":"news025,0003307498","type":"press","queryUrl":"sid=105"}' data-service-datetime="2023091311350000000">
# <a class="press_edit_news_link _es_pc_link" data-pc-link="" href="https://n.news.naver.com/article/025/0003307498?sid=105">
# <span class="press_edit_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/025/2023/09/13/3307498.jpg?type=nf212_140&amp;ut=1694572500000" height="70" onerror="showNoImage(this)" src="..." width="106"/>
# </span>
# <span class="press_edit_news_text">
# <span class="press_edit_news_title">KENTECH, 극성 산화물 표면 안정화 메커니즘 규명</span>
# <span class="r_ico_b r_modify is_outdated"><b>5시간전</b></span>
# </span>
# </a>
# </li>
# <li class="press_edit_news_item as_thumb _rcount" data-comment='{"gno":"news025,0003307490","type":"press","queryUrl":"sid=105"}' data-service-datetime="2023091311050000000">
# <a class="press_edit_news_link _es_pc_link" data-pc-link="" href="https://n.news.naver.com/article/025/0003307490?sid=105">
# <span class="press_edit_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/025/2023/09/13/3307490.jpg?type=nf212_140&amp;ut=1694570700000" height="70" onerror="showNoImage(this)" src="..." width="106"/>
# </span>
# <span class="press_edit_news_text">
# <span class="press_edit_news_title">KIST, 美로렌스리버모어 국립연구소와 공동 워크숍 개최</span>
# <span class="r_ico_b r_modify is_outdated"><b>6시간전</b></span>
# </span>
# </a>
# </li>
# <li class="press_edit_news_item as_thumb _rcount" data-comment='{"gno":"news025,0003307465","type":"press","queryUrl":"sid=105"}' data-service-datetime="2023091308212900000">
# <a class="press_edit_news_link _es_pc_link" data-pc-link="" href="https://n.news.naver.com/article/025/0003307465?sid=105">
# <span class="press_edit_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/025/2023/09/13/3307465.jpg?type=nf212_140&amp;ut=1694560889000" height="70" onerror="showNoImage(this)" src="..." width="106"/>
# </span>
# <span class="press_edit_news_text">
# <span class="press_edit_news_title">티타늄 입힌 아이폰15 공개된 날, 애플 주가는 하락했다</span>
# <span class="r_ico_b r_modify is_outdated"><b>8시간전</b></span>
# </span>
# </a>
# </li>
# <li class="press_edit_news_item as_thumb _rcount" data-comment='{"gno":"news025,0003307449","type":"press","queryUrl":"sid=105"}' data-service-datetime="2023091305000400000">
# <a class="press_edit_news_link _es_pc_link" data-pc-link="" href="https://n.news.naver.com/article/025/0003307449?sid=105">
# <span class="press_edit_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/025/2023/09/13/3307449.jpg?type=nf212_140&amp;ut=1694548804000" height="70" onerror="showNoImage(this)" src="..." width="106"/>
# </span>
# <span class="press_edit_news_text">
# <span class="press_edit_news_title">[단독] '택시대란' 없애려 요금 올렸더니, 기사·손님 다 내쫓았다 | 팩플</span>
# <span class="r_ico_b r_modify is_outdated"><b>12시간전</b></span>
# </span>
# </a>
# </li>
# <li class="press_edit_news_item as_thumb _rcount" data-comment='{"gno":"news025,0003307446","type":"press","queryUrl":"sid=105"}' data-service-datetime="2023091305000300000">
# <a class="press_edit_news_link _es_pc_link" data-pc-link="" href="https://n.news.naver.com/article/025/0003307446?sid=105">
# <span class="press_edit_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/025/2023/09/13/3307446.jpg?type=nf212_140&amp;ut=1694548803000" height="70" onerror="showNoImage(this)" src="..." width="106"/>
# </span>
# <span class="press_edit_news_text">
# <span class="press_edit_news_title">"통신비 인상 주범은 비싼 스마트폰…OTT 구독료도 한몫" [팩플]</span>
# <span class="r_ico_b r_modify is_outdated"><b>12시간전</b></span>
# </span>
# </a>
# </li>
# <li class="press_edit_news_item as_thumb _rcount" data-comment='{"gno":"news025,0003307396","type":"press","queryUrl":"sid=105"}' data-service-datetime="2023091300030000000">
# <a class="press_edit_news_link _es_pc_link" data-pc-link="" href="https://n.news.naver.com/article/025/0003307396?sid=105">
# <span class="press_edit_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/025/2023/09/13/3307396.jpg?type=nf212_140&amp;ut=1694530980000" height="70" onerror="showNoImage(this)" src="..." width="106"/>
# </span>
# <span class="press_edit_news_text">
# <span class="press_edit_news_title">[사진] 상하이에 뜬 갤럭시 Z 플립5</span>
# <span class="r_ico_b r_modify is_outdated"><b>17시간전</b></span>
# </span>
# </a>
# </li>
# <li class="press_edit_news_item as_thumb _rcount" data-comment='{"gno":"news025,0003307395","type":"press","queryUrl":"sid=105"}' data-service-datetime="2023091300030000000">
# <a class="press_edit_news_link _es_pc_link" data-pc-link="" href="https://n.news.naver.com/article/025/0003307395?sid=105">
# <span class="press_edit_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/025/2023/09/13/3307395.jpg?type=nf212_140&amp;ut=1694530980000" height="70" onerror="showNoImage(this)" src="..." width="106"/>
# </span>
# <span class="press_edit_news_text">
# <span class="press_edit_news_title">[사진] ICT 분야 수출상담회</span>
# <span class="r_ico_b r_modify is_outdated"><b>17시간전</b></span>
# </span>
# </a>
# </li>
# <li class="press_edit_news_item as_thumb _rcount" data-comment='{"gno":"news025,0003307271","type":"press","queryUrl":"sid=105"}' data-service-datetime="2023091216150000000">
# <a class="press_edit_news_link _es_pc_link" data-pc-link="" href="https://n.news.naver.com/article/025/0003307271?sid=105">
# <span class="press_edit_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/025/2023/09/12/3307271.jpg?type=nf212_140&amp;ut=1694502900000" height="70" onerror="showNoImage(this)" src="..." width="106"/>
# </span>
# <span class="press_edit_news_text">
# <span class="press_edit_news_title">한국발명진흥회, 日특허정보페어 참가</span>
# <span class="r_ico_b r_modify is_outdated"><b>1일전</b></span>
# </span>
# </a>
# </li>
# </ul>
# </div>
# <div class="press_edit_news">
# <ul class="press_edit_news_list as_5item_separator">
# <li class="press_edit_news_item as_thumb _rcount" data-comment='{"gno":"news025,0003307263","type":"press","queryUrl":"sid=105"}' data-service-datetime="2023091215522800000">
# <a class="press_edit_news_link _es_pc_link" data-pc-link="" href="https://n.news.naver.com/article/025/0003307263?sid=105">
# <span class="press_edit_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/025/2023/09/12/3307263.jpg?type=nf212_140&amp;ut=1694501548000" height="70" onerror="showNoImage(this)" src="..." width="106"/>
# <span class="r_ico r_vod"><em class="blind">동영상 뉴스</em></span>
# </span>
# <span class="press_edit_news_text">
# <span class="press_edit_news_title">손흥민, 팬 셀카 거절…"아이폰은 안 돼요" 만지지도 않는다 왜</span>
# <span class="r_ico_b r_modify is_outdated"><b>1일전</b></span>
# </span>
# </a>
# </li>
# <li class="press_edit_news_item as_thumb _rcount" data-comment='{"gno":"news025,0003307237","type":"press","queryUrl":"sid=105"}' data-service-datetime="2023091214270700000">
# <a class="press_edit_news_link _es_pc_link" data-pc-link="" href="https://n.news.naver.com/article/025/0003307237?sid=105">
# <span class="press_edit_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/025/2023/09/12/3307237.jpg?type=nf212_140&amp;ut=1694496427000" height="70" onerror="showNoImage(this)" src="..." width="106"/>
# </span>
# <span class="press_edit_news_text">
# <span class="press_edit_news_title">삼성전자에 전력 보낼 '송전선로’ 준공…용인 클러스터 '전력 공급' 협력</span>
# <span class="r_ico_b r_modify is_outdated"><b>1일전</b></span>
# </span>
# </a>
# </li>
# <li class="press_edit_news_item as_thumb _rcount" data-comment='{"gno":"news025,0003307155","type":"press","queryUrl":"sid=105"}' data-service-datetime="2023091207000000000">
# <a class="press_edit_news_link _es_pc_link" data-pc-link="" href="https://n.news.naver.com/article/025/0003307155?sid=105">
# <span class="press_edit_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/025/2023/09/12/3307155.jpg?type=nf212_140&amp;ut=1694469600000" height="70" onerror="showNoImage(this)" src="..." width="106"/>
# </span>
# <span class="press_edit_news_text">
# <span class="press_edit_news_title">[기고] 지능정보화 혁신으로 완성할 국가통계 원포털 비전</span>
# <span class="r_ico_b r_modify is_outdated"><b>1일전</b></span>
# </span>
# </a>
# </li>
# <li class="press_edit_news_item as_no_thumb _rcount" data-comment='{"gno":"news025,0003307091","type":"press","queryUrl":"sid=105"}' data-service-datetime="2023091200030000000">
# <a class="press_edit_news_link _es_pc_link" data-pc-link="" href="https://n.news.naver.com/article/025/0003307091?sid=105">
# <span class="press_edit_news_text">
# <span class="press_edit_news_title">중국 프리미엄폰·AI챗봇 반격에…희비 갈린 애플·마이크로소프트</span>
# <span class="r_ico_b r_modify is_outdated"><b>1일전</b></span>
# </span>
# </a>
# </li>
# <li class="press_edit_news_item as_thumb _rcount" data-comment='{"gno":"news025,0003307023","type":"press","queryUrl":"sid=105"}' data-service-datetime="2023091119100000000">
# <a class="press_edit_news_link _es_pc_link" data-pc-link="" href="https://n.news.naver.com/article/025/0003307023?sid=105">
# <span class="press_edit_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/025/2023/09/11/3307023.jpg?type=nf212_140&amp;ut=1694427000000" height="70" onerror="showNoImage(this)" src="..." width="106"/>
# </span>
# <span class="press_edit_news_text">
# <span class="press_edit_news_title">재료연, 제2회 스마트윈도우 산업기술 교류회 개최</span>
# <span class="r_ico_b r_modify is_outdated"><b>1일전</b></span>
# </span>
# </a>
# </li>
# <li class="press_edit_news_item as_thumb _rcount" data-comment='{"gno":"news025,0003307019","type":"press","queryUrl":"sid=105"}' data-service-datetime="2023091119000000000">
# <a class="press_edit_news_link _es_pc_link" data-pc-link="" href="https://n.news.naver.com/article/025/0003307019?sid=105">
# <span class="press_edit_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/025/2023/09/11/3307019.jpg?type=nf212_140&amp;ut=1694426400000" height="70" onerror="showNoImage(this)" src="..." width="106"/>
# </span>
# <span class="press_edit_news_text">
# <span class="press_edit_news_title">전기연구원, 헝가리에 SiC 전력반도체 이온 주입 평가기술 이전</span>
# <span class="r_ico_b r_modify is_outdated"><b>1일전</b></span>
# </span>
# </a>
# </li>
# <li class="press_edit_news_item as_thumb _rcount" data-comment='{"gno":"news025,0003307017","type":"press","queryUrl":"sid=105"}' data-service-datetime="2023091118500000000">
# <a class="press_edit_news_link _es_pc_link" data-pc-link="" href="https://n.news.naver.com/article/025/0003307017?sid=105">
# <span class="press_edit_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/025/2023/09/11/3307017.jpg?type=nf212_140&amp;ut=1694425800000" height="70" onerror="showNoImage(this)" src="..." width="106"/>
# </span>
# <span class="press_edit_news_text">
# <span class="press_edit_news_title">KEIT, 獨로보틱스 연구소와 협약 체결</span>
# <span class="r_ico_b r_modify is_outdated"><b>1일전</b></span>
# </span>
# </a>
# </li>
# <li class="press_edit_news_item as_thumb _rcount" data-comment='{"gno":"news025,0003306978","type":"press","queryUrl":"sid=105"}' data-service-datetime="2023091117200000000">
# <a class="press_edit_news_link _es_pc_link" data-pc-link="" href="https://n.news.naver.com/article/025/0003306978?sid=105">
# <span class="press_edit_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/025/2023/09/11/3306978.jpg?type=nf212_140&amp;ut=1694420400000" height="70" onerror="showNoImage(this)" src="..." width="106"/>
# </span>
# <span class="press_edit_news_text">
# <span class="press_edit_news_title">스마트스코어, 카카오VX 상대 법원 가처분 판결 유감 표명</span>
# <span class="r_ico_b r_modify is_outdated"><b>1일전</b></span>
# </span>
# </a>
# </li>
# <li class="press_edit_news_item as_thumb _rcount" data-comment='{"gno":"news025,0003306976","type":"press","queryUrl":"sid=105"}' data-service-datetime="2023091117164500000">
# <a class="press_edit_news_link _es_pc_link" data-pc-link="" href="https://n.news.naver.com/article/025/0003306976?sid=105">
# <span class="press_edit_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/025/2023/09/11/3306976.jpg?type=nf212_140&amp;ut=1694420205000" height="70" onerror="showNoImage(this)" src="..." width="106"/>
# </span>
# <span class="press_edit_news_text">
# <span class="press_edit_news_title">AI 예측 기술 기업 뉴로다임, 부산 실시간 교통흐름 제어 시스템 공급</span>
# <span class="r_ico_b r_modify is_outdated"><b>2일전</b></span>
# </span>
# </a>
# </li>
# <li class="press_edit_news_item as_thumb _rcount" data-comment='{"gno":"news025,0003306964","type":"press","queryUrl":"sid=105"}' data-service-datetime="2023091116500000000">
# <a class="press_edit_news_link _es_pc_link" data-pc-link="" href="https://n.news.naver.com/article/025/0003306964?sid=105">
# <span class="press_edit_news_thumb">
# <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/025/2023/09/11/3306964.jpg?type=nf212_140&amp;ut=1694418600000" height="70" onerror="showNoImage(this)" src="..." width="106"/>
# </span>
# <span class="press_edit_news_text">
# <span class="press_edit_news_title">LG이노텍 x 서울창조경제혁신센터 2023 스타트업 테크 블레이즈 개최</span>
# <span class="r_ico_b r_modify is_outdated"><b>2일전</b></span>
# </span>
# </a>
# </li>
# </ul>
# </div>
# <div class="r_more r_more_load _load_more_section_article">
# <div class="r_more_loader">
# <div class="r_more_loading_icon">
# <i class="r_more_dot as_1"></i>
# <i class="r_more_dot as_2"></i>
# <i class="r_more_dot as_3"></i>
# <i class="r_more_dot as_4"></i>
# <i class="r_more_dot as_5"></i>
# <i class="r_more_dot as_6"></i>
# </div>
# </div>
# </div>
# </div>

# %%
data2 = data1.findAll('span', {'class':'press_edit_news_title'})
pprint(data2)
# Out:
# [<span class="press_edit_news_title">경주시, ‘해오름동맹’ 벤처·창업기업 혁신포럼 개최</span>,
#  <span class="press_edit_news_title">[팩플] “AI 가장 잘 활용하는 국가로”…‘AI 일상화 계획’, 성공 조건은</span>,
#  <span class="press_edit_news_title">KENTECH, 극성 산화물 표면 안정화 메커니즘 규명</span>,
#  <span class="press_edit_news_title">KIST, 美로렌스리버모어 국립연구소와 공동 워크숍 개최</span>,
#  <span class="press_edit_news_title">티타늄 입힌 아이폰15 공개된 날, 애플 주가는 하락했다</span>,
#  <span class="press_edit_news_title">[단독] '택시대란' 없애려 요금 올렸더니, 기사·손님 다 내쫓았다 | 팩플</span>,
#  <span class="press_edit_news_title">"통신비 인상 주범은 비싼 스마트폰…OTT 구독료도 한몫" [팩플]</span>,
#  <span class="press_edit_news_title">[사진] 상하이에 뜬 갤럭시 Z 플립5</span>,
#  <span class="press_edit_news_title">[사진] ICT 분야 수출상담회</span>,
#  <span class="press_edit_news_title">한국발명진흥회, 日특허정보페어 참가</span>,
#  <span class="press_edit_news_title">손흥민, 팬 셀카 거절…"아이폰은 안 돼요" 만지지도 않는다 왜</span>,
#  <span class="press_edit_news_title">삼성전자에 전력 보낼 '송전선로’ 준공…용인 클러스터 '전력 공급' 협력</span>,
#  <span class="press_edit_news_title">[기고] 지능정보화 혁신으로 완성할 국가통계 원포털 비전</span>,
#  <span class="press_edit_news_title">중국 프리미엄폰·AI챗봇 반격에…희비 갈린 애플·마이크로소프트</span>,
#  <span class="press_edit_news_title">재료연, 제2회 스마트윈도우 산업기술 교류회 개최</span>,
#  <span class="press_edit_news_title">전기연구원, 헝가리에 SiC 전력반도체 이온 주입 평가기술 이전</span>,
#  <span class="press_edit_news_title">KEIT, 獨로보틱스 연구소와 협약 체결</span>,
#  <span class="press_edit_news_title">스마트스코어, 카카오VX 상대 법원 가처분 판결 유감 표명</span>,
#  <span class="press_edit_news_title">AI 예측 기술 기업 뉴로다임, 부산 실시간 교통흐름 제어 시스템 공급</span>,
#  <span class="press_edit_news_title">LG이노텍 x 서울창조경제혁신센터 2023 스타트업 테크 블레이즈 개최</span>]

# %%
title_list=[]

# %%
for t in data2:
    title_list.append(t.text)
# 텍스트만 추출하는 방법
# title_list = [t.text for t in data2] 리스트로 사용하면 간단하다

# %%
pprint(title_list)
# Out:
# ['경주시, ‘해오름동맹’ 벤처·창업기업 혁신포럼 개최',
#  '[팩플] “AI 가장 잘 활용하는 국가로”…‘AI 일상화 계획’, 성공 조건은',
#  'KENTECH, 극성 산화물 표면 안정화 메커니즘 규명',
#  'KIST, 美로렌스리버모어 국립연구소와 공동 워크숍 개최',
#  '티타늄 입힌 아이폰15 공개된 날, 애플 주가는 하락했다',
#  "[단독] '택시대란' 없애려 요금 올렸더니, 기사·손님 다 내쫓았다 | 팩플",
#  '"통신비 인상 주범은 비싼 스마트폰…OTT 구독료도 한몫" [팩플]',
#  '[사진] 상하이에 뜬 갤럭시 Z 플립5',
#  '[사진] ICT 분야 수출상담회',
#  '한국발명진흥회, 日특허정보페어 참가',
#  '손흥민, 팬 셀카 거절…"아이폰은 안 돼요" 만지지도 않는다 왜',
#  "삼성전자에 전력 보낼 '송전선로’ 준공…용인 클러스터 '전력 공급' 협력",
#  '[기고] 지능정보화 혁신으로 완성할 국가통계 원포털 비전',
#  '중국 프리미엄폰·AI챗봇 반격에…희비 갈린 애플·마이크로소프트',
#  '재료연, 제2회 스마트윈도우 산업기술 교류회 개최',
#  '전기연구원, 헝가리에 SiC 전력반도체 이온 주입 평가기술 이전',
#  'KEIT, 獨로보틱스 연구소와 협약 체결',
#  '스마트스코어, 카카오VX 상대 법원 가처분 판결 유감 표명',
#  'AI 예측 기술 기업 뉴로다임, 부산 실시간 교통흐름 제어 시스템 공급',
#  'LG이노텍 x 서울창조경제혁신센터 2023 스타트업 테크 블레이즈 개최']

# %%
find_AI = [s for s in title_list if "AI" in s]

# %%
pprint(find_AI)
# Out:
# ['[팩플] “AI 가장 잘 활용하는 국가로”…‘AI 일상화 계획’, 성공 조건은',
#  '중국 프리미엄폰·AI챗봇 반격에…희비 갈린 애플·마이크로소프트',
#  'AI 예측 기술 기업 뉴로다임, 부산 실시간 교통흐름 제어 시스템 공급']

# %%
pprint(find_AI.count("AI"))
# Out:
# 0

# %%
pprint(len(find_AI))
# Out:
# 3

# %%
# it뉴스란에 기사의 제목을 크롤링하여 AI라는 단어가 들어간 기사의 제목을 카운터 함
